# %%
import pandas as pd
import json

# %%
with open("menu.json","r") as menufile:
    menu=json.load(menufile)

# %%
len(menu)
# Out:
# 105

# %%
menu = [item if 'categoria' in item.keys() else item.update({'categoria': input(item['nome'])}) \
        for item in menu]
# Out:
# Coca-Cola® Zero SugarBeverages

# %%
menu
# Out:
# [{'ID': 30000,
#   'descrizione': 'A quarter-pound* of fresh beef, American cheese, crisp lettuce, tomato, pickle, ketchup, mayo, and onion on a toasted bun — just the way Dave intended.',
#   'nome': "Dave's Single®",
#   'calorie': '570 cal',
#   'prezzo': '$3.49',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197,
#    70214,
#    70215,
#    71567,
#    71570,
#    71569,
#    71571,
#    71539,
#    70222],
#   'tempoPreparazione': 3.5},
#  {'ID': 30001,
#   'descrizione': 'A half-pound* of fresh beef, American cheese, crisp lettuce, tomato, pickle, ketchup, mayo, and onion on a toasted bun. More meat means more to love.  ',
#   'nome': "Dave's Double®",
#   'calorie': '810 cal',
#   'prezzo': '$4.59',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197,
#    70214,
#    70215,
#    71567,
#    71570,
#    71569,
#    71571,
#    71539,
#    71151],
#   'tempoPreparazione': 3.5},
#  {'ID': 30002,
# ...

# %%
with open("menu.json", "w") as writefile:
    json.dump(menu, writefile, indent=1)
