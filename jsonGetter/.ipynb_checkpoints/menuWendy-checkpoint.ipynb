# %%
import pandas as pd
import json
import request
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-36-3536a6277a3a> in <module>
#       1 import pandas as pd
#       2 import json
# ----> 3 import request
#
# ModuleNotFoundError: No module named 'request'

# %%
with open("getSiteMenu.json","r") as filemenuog:
    menuog=json.load(filemenuog)

# %% [markdown]
# Per ottenere le immagini: https://app.wendys.com/unified/assets/menu/pg-cropped/"baseImageName"_medium_US_en.jpg

# %%
menuItems=menuog["menuLists"]["menuItems"]
menuItems
# Out:
# [{'baseImageName': '141',
#   'description': 'A quarter-pound* of fresh beef, American cheese, crisp lettuce, tomato, pickle, ketchup, mayo, and onion on a toasted bun — just the way Dave intended.',
#   'displayName': "Dave's Single®",
#   'name': "Dave's Single®",
#   'calorieRange': '570 cal',
#   'comboMenuItemId': 30836,
#   'defaultItemId': 40000,
#   'menuItemId': 30000,
#   'metaDescription': "We make Dave proud with our Dave's Single hamburger loaded with toppings and hand-crafted from a quarter pound of fresh 100% North American beef.",
#   'price': 0.0,
#   'priceRange': '$3.49',
#   'productGroupId': '141',
#   'promoId': 0,
#   'salesItemIds': [40000],
#   'titleTag': "Dave's Single Fresh Hamburgers - Hamburger Restaurant - Wendy's"},
#  {'baseImageName': '142',
#   'description': 'A half-pound* of fresh beef, American cheese, crisp lettuce, tomato, pickle, ketchup, mayo, and onion on a toasted bun. More meat means more to love.  ',
#   'displayName': "Dave's Double®",
#   'name': "Dave's Double®",
#   'calorieRange': '810 cal',
#   'comboMenuItemId': 30071,
#   'defaultItemId': 40001,
#   'menuItemId': 30001,
#   'metaDescription': "We make Dave proud with our Dave's Double hamburger loaded with toppings and hand-crafted from a half pound of fresh 100% North American beef.",
#   'price': 0.0,
#   'priceRange': '$4.59',
#   'productGroupId': '142',
#   'promoId': 0,
#   'salesItemIds': [40001],
#   'titleTag': "Dave's Double Fresh Hamburgers - Hamburger Restaurant - Wendy's"},
#  {'baseImageName': '143',
#   'description': 'Three quarters of a pound* of fresh, never frozen beef, American cheese, crisp lettuce, tomato, pickle, ketchup, mayo, and onion on a toasted bun. Use both hands!',
#   'displayName': "Dave's Triple®",
#   'name': "Dave's Triple®",
#   'calorieRange': '1,100 cal',
#   'comboMenuItemId': 30072,
#   'defaultItemId': 40002,
#   'menuItemId': 30002,
#   'metaDescription': "We make Dave proud with our Dave's Triple hamburger loaded with toppings and hand-crafted from a three-quarter pound of fresh 100% North American beef.",
#   'price': 0.0,
#   'priceRange': '$5.49',
#   'productGroupId': '143',
#   'promoId': 0,
#   'salesItemIds': [40002],
#   'titleTag': "Dave's Triple Fresh Hamburgers - Hamburger Restaurant - Wendy's"},
#  {'baseImageName': '144',
#   'description': 'A half-pound* of fresh beef, American cheese, 6 pieces of crispy Applewood smoked bacon, ketchup, and mayo. Carnivores rejoice!',
#   'displayName': 'Baconator®',
#   'name': 'Baconator®',
#   'calorieRange': '920 cal',
#   'comboMenuItemId': 30838,
#   'defaultItemId': 40003,
#   'menuItemId': 30003,
#   'metaDescription': "Enjoy bacon? Order the Baconator bacon cheeseburger from Wendy's today! Made with two 1/4 lb. fresh, never frozen, 100%  North American beef patties.",
#   'price': 0.0,
#   'priceRange': '$5.89',
#   'productGroupId': '144',
#   'promoId': 0,
#   'salesItemIds': [40003],
#   'titleTag': "Premium Double Bacon Burger with Fresh Hamburger Meat - Wendy's"},
#  {'baseImageName': '145',
#   'description': 'A quarter-pound of fresh beef, American cheese, plenty of Applewood smoked bacon, ketchup, and mayo. Like Baconator®, like Son. ',
#   'displayName': 'Son of Baconator®',
#   'name': 'Son of Baconator®',
#   'calorieRange': '630 cal',
#   'comboMenuItemId': 30074,
#   'defaultItemId': 40004,
#   'menuItemId': 30004,
#   'metaDescription': "Enjoy bacon? Order the Son of Baconator bacon cheeseburger from Wendy's. Made with fresh, never frozen, 100%  North American beef to meet your standards.",
#   'price': 0.0,
#   'priceRange': '$4.19',
#   'productGroupId': '145',
#   'promoId': 0,
#   'salesItemIds': [40004],
#   'titleTag': "Delicious Double Bacon Burger with Fresh Hamburger Meat - Wendy's"},
#  {'baseImageName': '146',
#   'description': 'Two patties of fresh, never frozen beef with cheese, ketchup, mustard, pickle, and onion. It’s double the fresh beef, stacked with deliciousness.',
#   'displayName': 'Double Stack™',
#   'name': 'Double Stack™',
#   'calorieRange': '390 cal',
#   'defaultItemId': 40005,
#   'menuItemId': 30005,
#   'metaDescription': "A double cheeseburger just the right size - Wendy's Double Stack made with 100% fresh North American beef with cheese, ketchup, mustard, pickle and onion.",
#   'price': 0.0,
#   'priceRange': '$1.79',
#   'productGroupId': '146',
#   'promoId': 0,
#   'salesItemIds': [40005],
#   'titleTag': "Junior Sized Double Cheeseburger - Double Stack - Wendy's"},
#  {'baseImageName': '147',
#   'description': 'Fresh beef, Applewood smoked bacon, American cheese, crisp lettuce, tomato, and mayo. It’s a favorite of bacon lovers everywhere.',
#   'displayName': 'Jr. Bacon Cheeseburger',
#   'name': 'Jr. Bacon Cheeseburger',
#   'calorieRange': '380 cal',
#   'comboMenuItemId': 30853,
#   'defaultItemId': 40006,
#   'menuItemId': 30006,
#   'metaDescription': "Just the right size bacon cheeseburger - Wendy's Junior Bacon Cheeseburger from our 4 for $4 menu with 100% fresh, never frozen North American beef.",
#   'price': 0.0,
#   'priceRange': '$1.60',
#   'productGroupId': '147',
#   'promoId': 0,
#   'salesItemIds': [40006],
#   'titleTag': "Junior Sized Bacon Cheeseburger - JBC - Wendy's"},
#  {'baseImageName': '148',
#   'description': 'Fresh beef topped with cheese, pickles, onions, tomatoes, crisp lettuce, ketchup, and mayo. It’s big flavor at a junior price. ',
#   'displayName': 'Jr. Cheeseburger Deluxe',
#   'name': 'Jr. Cheeseburger Deluxe',
#   'calorieRange': '340 cal',
#   'defaultItemId': 40007,
#   'menuItemId': 30007,
#   'metaDescription': "Right sized cheeseburger kicked up - Wendy's Junior Cheeseburger Deluxe with 100% fresh North American beef, cheese, pickles, onions, tomatoes and lettuce.",
#   'price': 0.0,
#   'priceRange': '$1.19',
#   'productGroupId': '148',
#   'promoId': 0,
#   'salesItemIds': [40007],
#   'titleTag': "Junior Sized Cheeseburger - Junior Cheeseburger Deluxe - Wendy's"},
#  {'baseImageName': '149',
#   'description': 'Fresh beef topped with cheese, pickles, onion, ketchup, and mustard on a toasted bun. It’s done just right, and just the right size.',
#   'displayName': 'Jr. Cheeseburger',
#   'name': 'Jr. Cheeseburger',
#   'calorieRange': '280 cal',
#   'comboMenuItemId': 30908,
#   'defaultItemId': 40008,
#   'menuItemId': 30008,
#   'metaDescription': "Just the right size cheeseburger - Wendy's Junior Cheeseburger with 100% fresh North American beef and topped with cheese, pickles, and onions. ",
#   'price': 0.0,
#   'priceRange': '$0.99',
#   'productGroupId': '149',
#   'promoId': 0,
#   'salesItemIds': [40008],
#   'titleTag': "Junior Sized Cheeseburger from Wendy's"},
#  {'baseImageName': '150',
#   'description': 'Fresh beef topped with pickles, onion, ketchup, and mustard on a toasted bun. It’s done just right, and just the right size.',
#   'displayName': 'Jr. Hamburger',
#   'name': 'Jr. Hamburger',
#   'calorieRange': '240 cal',
#   'defaultItemId': 40009,
#   'menuItemId': 30009,
#   'metaDescription': "Just the right size hamburger - Wendy's Junior Hamburger made with 100% fresh North American beef and is topped pickles and onions?hold the cheese!",
#   'price': 0.0,
#   'priceRange': '$0.99',
#   'productGroupId': '150',
#   'promoId': 0,
#   'salesItemIds': [40009],
#   'titleTag': "Junior Sized Hamburger from Wendy's"},
#  {'baseImageName': '167',
#   'description': 'A sizzling chicken breast grilled to perfection, with thick Applewood smoked bacon, Asiago cheese, creamy ranch sauce, crisp lettuce, and tomato, all on a toasted bun. Go grilled. Go home happy.',
#   'displayName': 'Grilled Asiago Ranch Club',
#   'name': 'Grilled Asiago Club',
#   'calorieRange': '500 cal',
#   'comboMenuItemId': 30080,
#   'defaultItemId': 40010,
#   'menuItemId': 30010,
#   'metaDescription': 'Our chicken is perfectly grilled and topped with crispy bacon, Asiago cheese, creamy ranch, lettuce and tomato – all on a toasted bun. Go grilled. Go home happy.',
#   'price': 0.0,
#   'priceRange': '$4.79',
#   'productGroupId': '167',
#   'promoId': 0,
#   'salesItemIds': [40010],
#   'titleTag': "Grilled Asiago Ranch Chicken Club Sandwich: Nutrition | Wendy's Menu"},
#  {'baseImageName': '156',
#   'description': 'A juicy, lightly breaded chicken breast taken over the top with thick Applewood smoked bacon, Asiago cheese, creamy ranch sauce, crisp lettuce, and tomato, all on a toasted bun. A club favorite that’s anything but boring.',
#   'displayName': 'Homestyle Asiago Ranch Chicken Club',
#   'name': 'Homestyle Asiago Club',
#   'calorieRange': '640 cal',
#   'comboMenuItemId': 30613,
#   'defaultItemId': 40011,
#   'menuItemId': 30011,
#   'metaDescription': 'Lightly breaded chicken breast, crispy bacon, Asiago cheese, creamy ranch, lettuce and tomato on a toasted bun. It’s a club sandwich that’s anything but boring.',
#   'price': 0.0,
#   'priceRange': '$4.82',
#   'productGroupId': '156',
#   'promoId': 0,
#   'salesItemIds': [40011],
#   'selectionLabel': 'STYLE',
#   'titleTag': "Homestyle Asiago Ranch Chicken Club: Nutrition | Wendy's Menu"},
#  {'baseImageName': '166',
#   'description': 'A juicy chicken breast marinated and breaded in our unique, fiery blend of peppers and spices to deliver more flavor inside and out, topped with thick Applewood smoked bacon, Asiago cheese, creamy ranch sauce, crisp lettuce, and tomato, all on a toasted bun. So hot you’ll wanna give your mouth a heads up. ',
#   'displayName': 'Spicy Asiago Ranch Club',
#   'name': 'Spicy Asiago Club',
#   'calorieRange': '630 cal',
#   'comboMenuItemId': 30082,
#   'defaultItemId': 40012,
#   'menuItemId': 30012,
#   'metaDescription': 'Add a twist to your club sandwich with our chicken breast, marinated in a fiery blend of peppers and spices. So hot, you’ll want to give your mouth a heads-up.',
#   'price': 0.0,
#   'priceRange': '$4.79',
#   'productGroupId': '166',
#   'promoId': 0,
#   'salesItemIds': [40012],
#   'titleTag': "Spicy Asiago Ranch Chicken Club Sandwich: Nutrition | Wendy's Menu"},
#  {'baseImageName': '151',
#   'description': 'A juicy chicken breast marinated and breaded in our unique, fiery blend of peppers and spices to deliver more flavor inside and out, cooled down with crisp lettuce, tomato, and mayo. It’s the original spicy chicken sandwich, and the one you crave.',
#   'displayName': 'Spicy Chicken Sandwich',
#   'name': 'Spicy Chicken Sandwich',
#   'calorieRange': '500 cal',
#   'comboMenuItemId': 30083,
#   'defaultItemId': 40013,
#   'menuItemId': 30013,
#   'metaDescription': "Try Wendy's fresh fast food Spicy Chicken Sandwich with a fiery blend of peppers and spices topped with mayo, hand-leafed lettuce, hand-sliced tomato.",
#   'price': 0.0,
#   'priceRange': '$4.39',
#   'productGroupId': '151',
#   'promoId': 0,
#   'salesItemIds': [40013],
#   'titleTag': "Spicy Chicken Sandwich - Fresh Fast Food Chicken - Wendy's"},
#  {'baseImageName': '153',
#   'description': 'A juicy, lightly-breaded chicken breast, crisp lettuce and tomato, and just enough mayo, all on a toasted bun. It’s extra comfy comfort food.',
#   'displayName': 'Homestyle Chicken Sandwich',
#   'name': 'Homestyle Chicken Sandwich',
#   'calorieRange': '500 cal',
#   'comboMenuItemId': 30084,
#   'defaultItemId': 40014,
#   'menuItemId': 30014,
#   'metaDescription': "Try Wendy's fresh fast food Homestyle Chicken Sandwich with specially seasoned breaded chicken topped with mayo, hand-leafed lettuce, hand-sliced tomato.",
#   'price': 0.0,
#   'priceRange': '$4.39',
#   'productGroupId': '153',
#   'promoId': 0,
#   'salesItemIds': [40014],
#   'titleTag': "Homestyle Chicken Sandwich - Fresh Fast Food Chicken - Wendy's"},
#  {'baseImageName': '155',
#   'description': 'Juicy white meat, lightly breaded and seasoned, topped with crisp lettuce, and mayo. More than delicious, and just the right size.',
#   'displayName': 'Crispy Chicken Sandwich',
#   'name': 'Crispy Chicken Sandwich',
#   'calorieRange': '330 cal',
#   'comboMenuItemId': 30907,
#   'defaultItemId': 40016,
#   'menuItemId': 30016,
#   'metaDescription': "Order Wendy's delicious fresh fast food Crispy Chicken Sandwich to go with a tender breaded chicken patty, creamy mayo and crisp hand-leafed lettuce.",
#   'price': 0.0,
#   'priceRange': '$0.99',
#   'productGroupId': '155',
#   'promoId': 0,
#   'salesItemIds': [40016],
#   'titleTag': "Crispy Chicken Sandwich - Fresh Fast Food Chicken - Wendy's"},
#  {'baseImageName': '942',
#   'description': '100% white-meat chicken breaded and marinated in our unique, fiery blend of peppers and spices. Served with your choice of six dipping sauces including Buttermilk Ranch, Creamy Sriracha, BBQ, Sweet & Sour, Honey Mustard or Side of S’Awesome®. The Internet icon is back for a hot minute.',
#   'displayName': '4 PC. Spicy Chicken Nuggets',
#   'name': '4 Piece Spicy Chicken Nuggets',
#   'calorieRange': '190 cal',
#   'defaultItemId': 40021,
#   'menuItemId': 30021,
#   'price': 0.0,
#   'priceRange': '$0.99',
#   'productGroupId': '942',
#   'promoId': 0,
#   'salesItemIds': [40021]},
#  {'baseImageName': '943',
#   'description': '100% white-meat chicken breaded and marinated in our unique, fiery blend of peppers and spices. Served with your choice of six dipping sauces including Buttermilk Ranch, Creamy Sriracha, BBQ, Sweet & Sour, Honey Mustard or Side of S’Awesome®. The Internet icon is back for a hot minute.',
#   'displayName': '6 PC. Spicy Chicken Nuggets',
#   'name': '6 Piece Spicy Chicken Nuggets',
#   'calorieRange': '280 cal',
#   'defaultItemId': 40023,
#   'menuItemId': 30023,
#   'price': 0.0,
#   'priceRange': '$1.49',
#   'productGroupId': '943',
#   'promoId': 0,
#   'salesItemIds': [40023]},
#  {'baseImageName': '727',
#   'description': '100% white-meat chicken breaded to crispy perfection and served with your choice of 6 dipping sauces including Buttermilk Ranch, Creamy Sriracha, BBQ, Sweet & Sour, Honey Mustard, or Side of S’Awesome®. They’re trending in our restaurants and Twitter feed alike.',
#   'displayName': '10 PC. Crispy Chicken Nuggets',
#   'name': '10 Piece Crispy Chicken Nuggets',
#   'calorieRange': '420 cal',
#   'comboMenuItemId': 30954,
#   'defaultItemId': 40024,
#   'menuItemId': 30024,
#   'metaDescription': 'Our 100% white-meat chicken is breaded to crispy perfection and served with two of your favorite dipping sauces. Grab a 10PC Chicken Nuggets to-go! ',
#   'price': 0.0,
#   'priceRange': '$4.69',
#   'productGroupId': '727',
#   'promoId': 0,
#   'salesItemIds': [40024],
#   'titleTag': "10 Piece Chicken Nuggets: Calories & Nutrition | Wendy's Menu"},
#  {'baseImageName': '161',
#   'description': 'Made fresh daily with Wendy’s signature lettuce blend, crisp red and green apples, dried cranberries, roasted pecans, crumbled blue cheese, and grilled chicken breast hot off the grill, all topped with Marzetti® Simply Dressed® Pomegranate Vinaigrette. An unbeatable pick.\r\n\r\nNutrition and allergen information is inclusive of all ingredients in this salad including two packets of dressing on the full-size salad and one packet on the half, which come on the side.\r\n',
#   'displayName': 'Apple Pecan Chicken Salad',
#   'name': 'Apple Pecan Chicken Salad',
#   'calorieRange': '340/570 cal',
#   'defaultItemId': 40033,
#   'menuItemId': 30027,
#   'metaDescription': "Try an Apple Pecan Chicken Salad to go from Wendy's with hand-picked apples, blue cheese, roasted pecans, grilled chicken and pomegranate vinaigrette.",
#   'price': 0.0,
#   'priceRange': '$4.09/$6.09',
#   'productGroupId': '161',
#   'promoId': 0,
#   'salesItemIds': [40033, 40034],
#   'titleTag': "Fast Food Salads To Go - Apple Pecan Chicken Salad - Wendy's"},
#  {'baseImageName': '833',
#   'description': 'Made fresh daily with romaine lettuce, grilled chicken breast, Italian cheeses, crunchy Parmesan crisps, and creamy Caesar dressing. One bite will tell you why it’s king of more than just the Romaines.',
#   'displayName': 'Parmesan Caesar Chicken Salad',
#   'name': 'Parmesan Caesar Chicken Salad',
#   'calorieRange': '310/560 cal',
#   'defaultItemId': 40037,
#   'menuItemId': 30028,
#   'metaDescription': 'Made fresh daily with romaine lettuce, grilled chicken, Italian cheeses, Parmesan crisps, and creamy Caesar dressing. Order a full or half-size.',
#   'price': 0.0,
#   'priceRange': '$4.79/$6.79',
#   'productGroupId': '833',
#   'promoId': 0,
#   'salesItemIds': [40037, 40038],
#   'titleTag': "Parmesan Caesar Chicken Salad - Grab One Near You | Wendy's Menu"},
#  {'baseImageName': '165',
#   'description': 'Natural-cut, skin-on, sea-salted fries served hot and crispy. The world loves them for a reason.',
#   'displayName': 'French Fries',
#   'name': 'French Fries',
#   'calorieRange': '220-480 cal',
#   'defaultItemId': 40054,
#   'menuItemId': 30032,
#   'metaDescription': "Let's face it, everybody has fries. Try the best fries from Wendy's, naturally-cut from whole Russet potatoes, cooked skin-on with sea salt.",
#   'price': 0.0,
#   'priceRange': '$0.99-$1.99',
#   'productGroupId': '165',
#   'promoId': 0,
#   'salesItemIds': [40053, 40054, 40055, 40056],
#   'titleTag': "Natural-Cut French Fries: Calories & Nutrition | Wendy's Menu"},
#  {'baseImageName': '170',
#   'description': 'Perfectly seasoned and positively irresistible. Red’s kind of our thing, you know.',
#   'displayName': 'Chili',
#   'name': 'Chili',
#   'calorieRange': '240/330 cal',
#   'defaultItemId': 40060,
#   'menuItemId': 30036,
#   'metaDescription': "Order a fast food chili to go from Wendy's with award-winning taste. Belly up to a pot of rich and meaty Chili that?s low in fat and high in fiber.",
#   'price': 0.0,
#   'priceRange': '$1.79/$2.49',
#   'productGroupId': '170',
#   'promoId': 0,
#   'salesItemIds': [40060, 40061],
#   'titleTag': "Fast Food Chili To Go - Rich and Meaty Chili - Wendy's"},
#  {'baseImageName': '1283',
#   'description': 'Strawberries served ripe and chilled. It’s a burst of summer flavor whenever you want them.',
#   'displayName': 'Strawberries',
#   'name': 'Strawberries',
#   'calorieRange': '20 cal',
#   'defaultItemId': 40067,
#   'menuItemId': 30038,
#   'price': 0.0,
#   'priceRange': '$1.79',
#   'productGroupId': '1283',
#   'promoId': 0,
#   'salesItemIds': [40067]},
#  {'baseImageName': '217',
#   'description': 'Our natural-cut, skin-on, sea-salted fries topped with warm, creamy cheese sauce, shredded cheddar, and crispy Applewood smoked bacon. The only fries worthy of the Baconator name.',
#   'displayName': 'Baconator Fries',
#   'name': 'Baconator Fries',
#   'calorieRange': '470 cal',
#   'defaultItemId': 40068,
#   'menuItemId': 30039,
#   'price': 0.0,
#   'priceRange': '$1.99',
#   'productGroupId': '217',
#   'promoId': 0,
#   'salesItemIds': [40068]},
#  {'baseImageName': '205',
#   'description': 'A blend of 100% Arabica beans from central and south America, medium-roasted to bring out all the best flavors.',
#   'displayName': 'Fresh Brewed Coffee',
#   'name': 'Coffee',
#   'calorieRange': '5 cal',
#   'defaultItemId': 40443,
#   'menuItemId': 30047,
#   'price': 0.0,
#   'priceRange': '$0.99/$1.29',
#   'productGroupId': '205',
#   'promoId': 0,
#   'salesItemIds': [40443, 40444]},
#  {'baseImageName': '206',
#   'description': 'Brewed to be rich and smooth without the caffeine. ',
#   'displayName': 'Fresh Brewed Decaffeinated Coffee',
#   'name': 'Decaffeinated Coffee',
#   'calorieRange': '0 cal',
#   'defaultItemId': 40445,
#   'menuItemId': 30048,
#   'price': 0.0,
#   'priceRange': '$0.99/$1.29',
#   'productGroupId': '206',
#   'promoId': 0,
#   'salesItemIds': [40445, 40446]},
#  {'baseImageName': '214',
#   'description': '1% milk with 30% of the daily calcium requirement.',
#   'displayName': 'Milk',
#   'name': 'Milk',
#   'calorieRange': '90 cal',
#   'defaultItemId': 40155,
#   'menuItemId': 30050,
#   'metaDescription': "Order healthy food options for a kid's meal with Milk that goes with everything and is also 25% of your recommended daily value for calcium!",
#   'price': 0.0,
#   'priceRange': '$1.29',
#   'productGroupId': '214',
#   'promoId': 0,
#   'salesItemIds': [40155],
#   'titleTag': "Kid's Meals - Healthy Options - Milk - Wendy's"},
#  {'baseImageName': '215',
#   'description': 'A favorite since forever with 25% the daily calcium requirement.',
#   'displayName': 'Chocolate Milk',
#   'name': 'Chocolate Milk',
#   'calorieRange': '140 cal',
#   'defaultItemId': 40156,
#   'menuItemId': 30051,
#   'metaDescription': "Order healthy food options for a kid's meal with Chocolate Milk that goes with everything and is also 25% of your recommended daily value for calcium!",
#   'price': 0.0,
#   'priceRange': '$1.29',
#   'productGroupId': '215',
#   'promoId': 0,
#   'salesItemIds': [40156],
#   'titleTag': "Kid's Meals - Healthy Options - Chocolate Milk - Wendy's"},
#  {'baseImageName': '179',
#   'description': 'The Chocolate Frosty® was born out of Dave’s desire for a signature dessert to go with his vision of the perfect meal. Thick enough to use a spoon, smooth enough to use a straw, and perfect when enjoyed on the end of a fry. ',
#   'displayName': 'Classic Chocolate Frosty®',
#   'name': 'Chocolate Frosty®',
#   'calorieRange': '200-590 cal',
#   'defaultItemId': 40165,
#   'menuItemId': 30053,
#   'metaDescription': 'Thick enough to use a spoon, smooth enough for a straw, perfect on the end of a fry. Treat yourself to our signature dessert – order a Chocolate Frosty® today!',
#   'price': 0.0,
#   'priceRange': '$0.89-$1.89',
#   'productGroupId': '179',
#   'promoId': 0,
#   'salesItemIds': [40163, 40165, 40164, 40166],
#   'titleTag': "Classic Chocolate Frosty®: Jr, Small, Medium & Large | Wendy's Menu"},
#  {'baseImageName': '180',
#   'description': 'The vanilla version of our signature frozen dessert. Cool and creamy don’t do it justice. This is the smooth, thick, sweet dessert masterpiece that goes with everything on our menu. You deserve a dessert this good, so go ahead.',
#   'displayName': 'Vanilla Frosty®',
#   'name': 'Vanilla Frosty®',
#   'calorieRange': '190-570 cal',
#   'defaultItemId': 40168,
#   'menuItemId': 30054,
#   'metaDescription': 'Get a cool, creamy, refreshing Vanilla Frosty®. Cuz nothing beats Wendy’s famous frozen dairy dessert, made from fresh Grade A milk and rich cream.',
#   'price': 0.0,
#   'priceRange': '$0.89-$1.89',
#   'productGroupId': '180',
#   'promoId': 0,
#   'salesItemIds': [40167, 40168, 40169, 40170],
#   'titleTag': "Vanilla Frosty®: Jr, Small, Medium & Large | Wendy's Menu"},
#  {'baseImageName': '581',
#   'description': 'Give yourself a wholesome start to the day with our Fresh Baked Oatmeal Bar made with whole oats, sweet blueberries and tart cranberries.\r\n',
#   'displayName': 'Oatmeal Bar',
#   'name': 'Oatmeal Bar',
#   'calorieRange': '270 cal',
#   'defaultItemId': 40176,
#   'menuItemId': 30057,
#   'price': 0.0,
#   'priceRange': '$1.39',
#   'productGroupId': '581',
#   'promoId': 0,
#   'salesItemIds': [40176]},
#  {'baseImageName': '451',
#   'description': 'A rich, soft, fresh-baked cookie full of semi-sweet chunks of chocolate, baked in-house. Grandma would love them.',
#   'displayName': 'Chocolate Chunk Cookie',
#   'name': 'Chocolate Chunk Cookie',
#   'calorieRange': '330 cal',
#   'defaultItemId': 40177,
#   'menuItemId': 30058,
#   'price': 0.0,
#   'priceRange': '$1.39',
#   'productGroupId': '451',
#   'promoId': 0,
#   'salesItemIds': [40177]},
#  {'baseImageName': '453',
#   'description': 'The traditional favorite. Soft, fresh-baked, simple, and perfect.',
#   'displayName': 'Sugar Cookie',
#   'name': 'Sugar Cookie',
#   'calorieRange': '330 cal',
#   'defaultItemId': 40178,
#   'menuItemId': 30059,
#   'price': 0.0,
#   'priceRange': '$1.39',
#   'productGroupId': '453',
#   'promoId': 0,
#   'salesItemIds': [40178]},
#  {'baseImageName': '452',
#   'description': 'A soft, fresh-baked chocolate cookie with chocolate chunks, baked in-house. Chocolate and chocolate, together at last.',
#   'displayName': 'Double Chocolate Chip Cookie',
#   'name': 'Double Chocolate Chip Cookie',
#   'calorieRange': '290 cal',
#   'defaultItemId': 40179,
#   'menuItemId': 30060,
#   'price': 0.0,
#   'priceRange': '$1.39',
#   'productGroupId': '452',
#   'promoId': 0,
#   'salesItemIds': [40179]},
#  {'baseImageName': '',
#   'description': '',
#   'displayName': '',
#   'name': 'Base Combo',
#   'defaultItemId': 40714,
#   'menuItemId': 30070,
#   'price': 0.0,
#   'promoId': 0,
#   'salesGroups': [{'description': 'Single Combo',
#     'displayName': 'Base Combo',
#     'name': 'Base Combo',
#     'defaultSalesItemId': 40714,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635743783251520817},
#    {'description': 'Combo Sides',
#     'displayName': 'Side',
#     'name': 'Side',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113329953416,
#     'salesGroupIds': [165,
#      913,
#      217,
#      455,
#      171,
#      175,
#      172,
#      174,
#      176,
#      170,
#      449,
#      1283],
#     'salesItemIds': [40204,
#      40205,
#      40206,
#      41584,
#      40207,
#      41042,
#      40307,
#      40309,
#      40308,
#      40311,
#      40310,
#      40316,
#      40317,
#      40813,
#      40067]},
#    {'description': 'Combo Drinks',
#     'displayName': 'Drink',
#     'name': 'Drink',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113459456365,
#     'salesGroupIds': [181,
#      183,
#      182,
#      184,
#      192,
#      423,
#      194,
#      193,
#      197,
#      195,
#      198,
#      199,
#      830,
#      831,
#      196,
#      200,
#      201,
#      216,
#      205,
#      206,
#      214,
#      215,
#      535,
#      533,
#      534,
#      829],
#     'salesItemIds': [40201,
#      40202,
#      40203,
#      40230,
#      40231,
#      40232,
#      40209,
#      40210,
#      40211,
#      40212,
#      40213,
#      40214,
#      40215,
#      40216,
#      40217,
#      40236,
#      40237,
#      40238,
#      40221,
#      40222,
#      40223,
#      40218,
#      40219,
#      40220,
#      40227,
#      40228,
#      40229,
#      40224,
#      40225,
#      40226,
#      40275,
#      40276,
#      40277,
#      40272,
#      40273,
#      40305,
#      41436,
#      41437,
#      41438,
#      41442,
#      41443,
#      41444,
#      40278,
#      40279,
#      40280,
#      40287,
#      40288,
#      40289,
#      40281,
#      40282,
#      40283,
#      40328,
#      41022,
#      41023,
#      41024,
#      41025,
#      40330,
#      40329,
#      41259,
#      41260,
#      41263,
#      41264,
#      41267,
#      41268,
#      41600]}],
#   'salesItemIds': [40207,
#    40206,
#    40205,
#    40201,
#    40204,
#    40203,
#    40202,
#    40232,
#    40211,
#    40217,
#    40238,
#    40226,
#    40229,
#    40220,
#    40223,
#    40214,
#    40231,
#    40210,
#    40216,
#    40237,
#    40225,
#    40228,
#    40219,
#    40222,
#    40213,
#    40230,
#    40209,
#    40215,
#    40236,
#    40224,
#    40227,
#    40218,
#    40221,
#    40212,
#    40277,
#    40280,
#    40289,
#    40283,
#    40305,
#    40276,
#    40279,
#    40288,
#    40282,
#    40273,
#    40275,
#    40278,
#    40287,
#    40281,
#    40272,
#    40307,
#    40308,
#    40309,
#    40317,
#    40310,
#    40316,
#    40311,
#    40328,
#    40329,
#    40330,
#    40813,
#    41022,
#    41023,
#    41024,
#    41025,
#    41042,
#    41259,
#    41260,
#    41263,
#    41264,
#    41267,
#    41268,
#    41436,
#    41437,
#    41438,
#    41442,
#    41443,
#    41444,
#    41584,
#    41600,
#    40067]},
#  {'baseImageName': '263',
#   'description': 'A half-pound* of fresh beef, American cheese, crisp lettuce, tomato, pickle, ketchup, mayo, and onion on a toasted bun. More meat means more to love.  ',
#   'displayName': "Dave's Double®",
#   'name': "Dave's Double® Combo",
#   'calorieRange': '850-1,460 cal',
#   'comboConfigId': 1,
#   'defaultItemId': 40001,
#   'menuItemId': 30071,
#   'price': 6.49,
#   'priceRange': '$6.49',
#   'productGroupId': '263',
#   'promoId': 2067,
#   'salesGroups': [{'description': 'Double Combo',
#     'displayName': 'Double Combo',
#     'name': 'Double Combo',
#     'defaultSalesItemId': 40001,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635743786677930253,
#     'salesItemIds': [40001]},
#    {'description': 'Combo Sides',
#     'displayName': 'Side',
#     'name': 'Side',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113329953416,
#     'salesGroupIds': [165,
#      913,
#      217,
#      455,
#      171,
#      175,
#      172,
#      174,
#      176,
#      170,
#      449,
#      1283],
#     'salesItemIds': [40204,
#      40205,
#      40206,
#      41584,
#      40207,
#      41042,
#      40307,
#      40309,
#      40308,
#      40311,
#      40310,
#      40316,
#      40317,
#      40813,
#      40067]},
#    {'description': 'Combo Drinks',
#     'displayName': 'Drink',
#     'name': 'Drink',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113459456365,
#     'salesGroupIds': [181,
#      183,
#      182,
#      184,
#      192,
#      423,
#      194,
#      193,
#      197,
#      195,
#      198,
#      199,
#      830,
#      831,
#      196,
#      200,
#      201,
#      216,
#      205,
#      206,
#      214,
#      215,
#      535,
#      533,
#      534,
#      829],
#     'salesItemIds': [40201,
#      40202,
#      40203,
#      40230,
#      40231,
#      40232,
#      40209,
#      40210,
#      40211,
#      40212,
#      40213,
#      40214,
#      40215,
#      40216,
#      40217,
#      40236,
#      40237,
#      40238,
#      40221,
#      40222,
#      40223,
#      40218,
#      40219,
#      40220,
#      40227,
#      40228,
#      40229,
#      40224,
#      40225,
#      40226,
#      40275,
#      40276,
#      40277,
#      40272,
#      40273,
#      40305,
#      41436,
#      41437,
#      41438,
#      41442,
#      41443,
#      41444,
#      40278,
#      40279,
#      40280,
#      40287,
#      40288,
#      40289,
#      40281,
#      40282,
#      40283,
#      40328,
#      41022,
#      41023,
#      41024,
#      41025,
#      40330,
#      40329,
#      41259,
#      41260,
#      41263,
#      41264,
#      41267,
#      41268,
#      41600]}],
#   'salesItemIds': [40001,
#    40203,
#    40202,
#    40201,
#    40206,
#    40205,
#    40204,
#    40232,
#    40211,
#    40217,
#    40238,
#    40226,
#    40277,
#    40229,
#    40280,
#    40220,
#    40223,
#    40214,
#    40289,
#    40283,
#    40305,
#    40231,
#    40210,
#    40216,
#    40237,
#    40225,
#    40276,
#    40228,
#    40279,
#    40219,
#    40222,
#    40213,
#    40288,
#    40282,
#    40273,
#    40230,
#    40209,
#    40215,
#    40236,
#    40224,
#    40275,
#    40227,
#    40278,
#    40218,
#    40221,
#    40212,
#    40287,
#    40281,
#    40272]},
#  {'baseImageName': '264',
#   'description': 'Three quarters of a pound* of fresh, never frozen beef, American cheese, crisp lettuce, tomato, pickle, ketchup, mayo, and onion on a toasted bun. Use both hands!',
#   'displayName': "Dave's Triple®",
#   'name': "Dave's Triple® Combo",
#   'calorieRange': '1,130-1,740 cal',
#   'comboConfigId': 1,
#   'defaultItemId': 40002,
#   'menuItemId': 30072,
#   'price': 7.59,
#   'priceRange': '$7.59',
#   'productGroupId': '264',
#   'promoId': 2068,
#   'salesGroups': [{'description': 'Triple Combo',
#     'displayName': 'Triple Combo',
#     'name': 'Triple Combo',
#     'defaultSalesItemId': 40002,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635744062720983363,
#     'salesItemIds': [40002]},
#    {'description': 'Combo Sides',
#     'displayName': 'Side',
#     'name': 'Side',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113329953416,
#     'salesGroupIds': [165,
#      913,
#      217,
#      455,
#      171,
#      175,
#      172,
#      174,
#      176,
#      170,
#      449,
#      1283],
#     'salesItemIds': [40204,
#      40205,
#      40206,
#      41584,
#      40207,
#      41042,
#      40307,
#      40309,
#      40308,
#      40311,
#      40310,
#      40316,
#      40317,
#      40813,
#      40067]},
#    {'description': 'Combo Drinks',
#     'displayName': 'Drink',
#     'name': 'Drink',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113459456365,
#     'salesGroupIds': [181,
#      183,
#      182,
#      184,
#      192,
#      423,
#      194,
#      193,
#      197,
#      195,
#      198,
#      199,
#      830,
#      831,
#      196,
#      200,
#      201,
#      216,
#      205,
#      206,
#      214,
#      215,
#      535,
#      533,
#      534,
#      829],
#     'salesItemIds': [40201,
#      40202,
#      40203,
#      40230,
#      40231,
#      40232,
#      40209,
#      40210,
#      40211,
#      40212,
#      40213,
#      40214,
#      40215,
#      40216,
#      40217,
#      40236,
#      40237,
#      40238,
#      40221,
#      40222,
#      40223,
#      40218,
#      40219,
#      40220,
#      40227,
#      40228,
#      40229,
#      40224,
#      40225,
#      40226,
#      40275,
#      40276,
#      40277,
#      40272,
#      40273,
#      40305,
#      41436,
#      41437,
#      41438,
#      41442,
#      41443,
#      41444,
#      40278,
#      40279,
#      40280,
#      40287,
#      40288,
#      40289,
#      40281,
#      40282,
#      40283,
#      40328,
#      41022,
#      41023,
#      41024,
#      41025,
#      40330,
#      40329,
#      41259,
#      41260,
#      41263,
#      41264,
#      41267,
#      41268,
#      41600]}],
#   'salesItemIds': [40002, 40206, 40203, 40202, 40205, 40201, 40204]},
#  {'baseImageName': '265',
#   'description': 'A half-pound* of fresh beef, American cheese, 6 pieces of crispy Applewood smoked bacon, ketchup, and mayo. Carnivores rejoice!',
#   'displayName': 'Baconator®',
#   'name': 'Baconator® Combo',
#   'calorieRange': '980-1,600 cal',
#   'comboConfigId': 1,
#   'defaultItemId': 40003,
#   'menuItemId': 30073,
#   'price': 7.99,
#   'priceRange': '$7.99',
#   'productGroupId': '265',
#   'promoId': 4356,
#   'salesGroups': [{'description': 'Baconator Combo',
#     'displayName': 'Baconator Combo',
#     'name': 'Baconator Combo',
#     'defaultSalesItemId': 40003,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635744065603168840,
#     'salesItemIds': [40003]},
#    {'description': 'Combo Sides',
#     'displayName': 'Side',
#     'name': 'Side',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113329953416,
#     'salesGroupIds': [165,
#      913,
#      217,
#      455,
#      171,
#      175,
#      172,
#      174,
#      176,
#      170,
#      449,
#      1283],
#     'salesItemIds': [40204,
#      40205,
#      40206,
#      41584,
#      40207,
#      41042,
#      40307,
#      40309,
#      40308,
#      40311,
#      40310,
#      40316,
#      40317,
#      40813,
#      40067]},
#    {'description': 'Combo Drinks',
#     'displayName': 'Drink',
#     'name': 'Drink',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113459456365,
#     'salesGroupIds': [181,
#      183,
#      182,
#      184,
#      192,
#      423,
#      194,
#      193,
#      197,
#      195,
#      198,
#      199,
#      830,
#      831,
#      196,
#      200,
#      201,
#      216,
#      205,
#      206,
#      214,
#      215,
#      535,
#      533,
#      534,
#      829],
#     'salesItemIds': [40201,
#      40202,
#      40203,
#      40230,
#      40231,
#      40232,
#      40209,
#      40210,
#      40211,
#      40212,
#      40213,
#      40214,
#      40215,
#      40216,
#      40217,
#      40236,
#      40237,
#      40238,
#      40221,
#      40222,
#      40223,
#      40218,
#      40219,
#      40220,
#      40227,
#      40228,
#      40229,
#      40224,
#      40225,
#      40226,
#      40275,
#      40276,
#      40277,
#      40272,
#      40273,
#      40305,
#      41436,
#      41437,
#      41438,
#      41442,
#      41443,
#      41444,
#      40278,
#      40279,
#      40280,
#      40287,
#      40288,
#      40289,
#      40281,
#      40282,
#      40283,
#      40328,
#      41022,
#      41023,
#      41024,
#      41025,
#      40330,
#      40329,
#      41259,
#      41260,
#      41263,
#      41264,
#      41267,
#      41268,
#      41600]}],
#   'salesItemIds': [40003, 40206, 40203, 40202, 40205, 40201, 40204]},
#  {'baseImageName': '266',
#   'description': 'A quarter-pound of fresh beef, American cheese, plenty of Applewood smoked bacon, ketchup, and mayo. Like Baconator®, like Son. ',
#   'displayName': 'Son of Baconator®',
#   'name': 'Son of Baconator® Combo',
#   'calorieRange': '670-1,280 cal',
#   'comboConfigId': 1,
#   'defaultItemId': 40004,
#   'menuItemId': 30074,
#   'price': 6.09,
#   'priceRange': '$6.09',
#   'productGroupId': '266',
#   'promoId': 5602,
#   'salesGroups': [{'description': 'Son of Baconator Combo',
#     'displayName': 'Son of Baconator Combo',
#     'name': 'Son of Baconator Combo',
#     'defaultSalesItemId': 40004,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635744067692111191,
#     'salesItemIds': [40004]},
#    {'description': 'Combo Sides',
#     'displayName': 'Side',
#     'name': 'Side',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113329953416,
#     'salesGroupIds': [165,
#      913,
#      217,
#      455,
#      171,
#      175,
#      172,
#      174,
#      176,
#      170,
#      449,
#      1283],
#     'salesItemIds': [40204,
#      40205,
#      40206,
#      41584,
#      40207,
#      41042,
#      40307,
#      40309,
#      40308,
#      40311,
#      40310,
#      40316,
#      40317,
#      40813,
#      40067]},
#    {'description': 'Combo Drinks',
#     'displayName': 'Drink',
#     'name': 'Drink',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113459456365,
#     'salesGroupIds': [181,
#      183,
#      182,
#      184,
#      192,
#      423,
#      194,
#      193,
#      197,
#      195,
#      198,
#      199,
#      830,
#      831,
#      196,
#      200,
#      201,
#      216,
#      205,
#      206,
#      214,
#      215,
#      535,
#      533,
#      534,
#      829],
#     'salesItemIds': [40201,
#      40202,
#      40203,
#      40230,
#      40231,
#      40232,
#      40209,
#      40210,
#      40211,
#      40212,
#      40213,
#      40214,
#      40215,
#      40216,
#      40217,
#      40236,
#      40237,
#      40238,
#      40221,
#      40222,
#      40223,
#      40218,
#      40219,
#      40220,
#      40227,
#      40228,
#      40229,
#      40224,
#      40225,
#      40226,
#      40275,
#      40276,
#      40277,
#      40272,
#      40273,
#      40305,
#      41436,
#      41437,
#      41438,
#      41442,
#      41443,
#      41444,
#      40278,
#      40279,
#      40280,
#      40287,
#      40288,
#      40289,
#      40281,
#      40282,
#      40283,
#      40328,
#      41022,
#      41023,
#      41024,
#      41025,
#      40330,
#      40329,
#      41259,
#      41260,
#      41263,
#      41264,
#      41267,
#      41268,
#      41600]}],
#   'salesItemIds': [40004, 40206, 40203, 40202, 40205, 40201, 40204]},
#  {'baseImageName': '666',
#   'description': 'A sizzling chicken breast grilled to perfection, with thick Applewood smoked bacon, Asiago cheese, creamy ranch sauce, crisp lettuce, and tomato, all on a toasted bun. Go grilled. Go home happy.',
#   'displayName': 'Grilled Asiago Ranch Chicken Club',
#   'name': 'Grilled Asiago Club Combo',
#   'calorieRange': '560-1,180 cal',
#   'comboConfigId': 1,
#   'defaultItemId': 40010,
#   'menuItemId': 30080,
#   'price': 6.79,
#   'priceRange': '$6.79',
#   'productGroupId': '666',
#   'promoId': 5011,
#   'salesGroups': [{'description': 'Grilled Asiago Club Combo',
#     'displayName': 'Grilled Asiago Club Combo',
#     'name': 'Grilled Asiago Club Combo',
#     'defaultSalesItemId': 40010,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635744700085907682,
#     'salesItemIds': [40010]},
#    {'description': 'Combo Sides',
#     'displayName': 'Side',
#     'name': 'Side',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113329953416,
#     'salesGroupIds': [165,
#      913,
#      217,
#      455,
#      171,
#      175,
#      172,
#      174,
#      176,
#      170,
#      449,
#      1283],
#     'salesItemIds': [40204,
#      40205,
#      40206,
#      41584,
#      40207,
#      41042,
#      40307,
#      40309,
#      40308,
#      40311,
#      40310,
#      40316,
#      40317,
#      40813,
#      40067]},
#    {'description': 'Combo Drinks',
#     'displayName': 'Drink',
#     'name': 'Drink',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113459456365,
#     'salesGroupIds': [181,
#      183,
#      182,
#      184,
#      192,
#      423,
#      194,
#      193,
#      197,
#      195,
#      198,
#      199,
#      830,
#      831,
#      196,
#      200,
#      201,
#      216,
#      205,
#      206,
#      214,
#      215,
#      535,
#      533,
#      534,
#      829],
#     'salesItemIds': [40201,
#      40202,
#      40203,
#      40230,
#      40231,
#      40232,
#      40209,
#      40210,
#      40211,
#      40212,
#      40213,
#      40214,
#      40215,
#      40216,
#      40217,
#      40236,
#      40237,
#      40238,
#      40221,
#      40222,
#      40223,
#      40218,
#      40219,
#      40220,
#      40227,
#      40228,
#      40229,
#      40224,
#      40225,
#      40226,
#      40275,
#      40276,
#      40277,
#      40272,
#      40273,
#      40305,
#      41436,
#      41437,
#      41438,
#      41442,
#      41443,
#      41444,
#      40278,
#      40279,
#      40280,
#      40287,
#      40288,
#      40289,
#      40281,
#      40282,
#      40283,
#      40328,
#      41022,
#      41023,
#      41024,
#      41025,
#      40330,
#      40329,
#      41259,
#      41260,
#      41263,
#      41264,
#      41267,
#      41268,
#      41600]}],
#   'salesItemIds': [40010, 40206, 40203, 40202, 40205, 40201, 40204]},
#  {'baseImageName': '598',
#   'description': 'A juicy, lightly breaded chicken breast taken over the top with thick Applewood smoked bacon, Asiago cheese, creamy ranch sauce, crisp lettuce, and tomato, all on a toasted bun. A club favorite that’s anything but boring.',
#   'displayName': 'Homestyle  Asiago Ranch Chicken Club',
#   'name': 'Homestyle Asiago Club Combo',
#   'calorieRange': '700-1,320 cal',
#   'comboConfigId': 1,
#   'defaultItemId': 40011,
#   'menuItemId': 30081,
#   'price': 6.79,
#   'priceRange': '$6.79',
#   'productGroupId': '598',
#   'promoId': 5017,
#   'salesGroups': [{'description': 'Homestyle Asiago  Club Combo',
#     'displayName': 'Homestyle Asiago  Club Combo',
#     'name': 'Homestyle Asiago  Club Combo',
#     'defaultSalesItemId': 40011,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635744701848909373,
#     'salesItemIds': [40011]},
#    {'description': 'Combo Sides',
#     'displayName': 'Side',
#     'name': 'Side',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113329953416,
#     'salesGroupIds': [165,
#      913,
#      217,
#      455,
#      171,
#      175,
#      172,
#      174,
#      176,
#      170,
#      449,
#      1283],
#     'salesItemIds': [40204,
#      40205,
#      40206,
#      41584,
#      40207,
#      41042,
#      40307,
#      40309,
#      40308,
#      40311,
#      40310,
#      40316,
#      40317,
#      40813,
#      40067]},
#    {'description': 'Combo Drinks',
#     'displayName': 'Drink',
#     'name': 'Drink',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113459456365,
#     'salesGroupIds': [181,
#      183,
#      182,
#      184,
#      192,
#      423,
#      194,
#      193,
#      197,
#      195,
#      198,
#      199,
#      830,
#      831,
#      196,
#      200,
#      201,
#      216,
#      205,
#      206,
#      214,
#      215,
#      535,
#      533,
#      534,
#      829],
#     'salesItemIds': [40201,
#      40202,
#      40203,
#      40230,
#      40231,
#      40232,
#      40209,
#      40210,
#      40211,
#      40212,
#      40213,
#      40214,
#      40215,
#      40216,
#      40217,
#      40236,
#      40237,
#      40238,
#      40221,
#      40222,
#      40223,
#      40218,
#      40219,
#      40220,
#      40227,
#      40228,
#      40229,
#      40224,
#      40225,
#      40226,
#      40275,
#      40276,
#      40277,
#      40272,
#      40273,
#      40305,
#      41436,
#      41437,
#      41438,
#      41442,
#      41443,
#      41444,
#      40278,
#      40279,
#      40280,
#      40287,
#      40288,
#      40289,
#      40281,
#      40282,
#      40283,
#      40328,
#      41022,
#      41023,
#      41024,
#      41025,
#      40330,
#      40329,
#      41259,
#      41260,
#      41263,
#      41264,
#      41267,
#      41268,
#      41600]}],
#   'salesItemIds': [40011, 40206, 40205, 40204, 40203, 40202, 40201]},
#  {'baseImageName': '599',
#   'description': 'A juicy chicken breast marinated and breaded in our unique, fiery blend of peppers and spices to deliver more flavor inside and out, topped with thick Applewood smoked bacon, Asiago cheese, creamy ranch sauce, crisp lettuce, and tomato, all on a toasted bun. So hot you’ll wanna give your mouth a heads up. ',
#   'displayName': 'Spicy Asiago Ranch Chicken Club',
#   'name': 'Spicy Asiago Club Combo',
#   'calorieRange': '710-1,320 cal',
#   'comboConfigId': 1,
#   'defaultItemId': 40012,
#   'menuItemId': 30082,
#   'price': 6.79,
#   'priceRange': '$6.79',
#   'productGroupId': '599',
#   'promoId': 5007,
#   'salesGroups': [{'description': 'Spicy Asiago Club Combo',
#     'displayName': 'Spicy Asiago Club Combo',
#     'name': 'Spicy Asiago Club Combo',
#     'defaultSalesItemId': 40012,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635744708812220719,
#     'salesItemIds': [40012]},
#    {'description': 'Combo Sides',
#     'displayName': 'Side',
#     'name': 'Side',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113329953416,
#     'salesGroupIds': [165,
#      913,
#      217,
#      455,
#      171,
#      175,
#      172,
#      174,
#      176,
#      170,
#      449,
#      1283],
#     'salesItemIds': [40204,
#      40205,
#      40206,
#      41584,
#      40207,
#      41042,
#      40307,
#      40309,
#      40308,
#      40311,
#      40310,
#      40316,
#      40317,
#      40813,
#      40067]},
#    {'description': 'Combo Drinks',
#     'displayName': 'Drink',
#     'name': 'Drink',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113459456365,
#     'salesGroupIds': [181,
#      183,
#      182,
#      184,
#      192,
#      423,
#      194,
#      193,
#      197,
#      195,
#      198,
#      199,
#      830,
#      831,
#      196,
#      200,
#      201,
#      216,
#      205,
#      206,
#      214,
#      215,
#      535,
#      533,
#      534,
#      829],
#     'salesItemIds': [40201,
#      40202,
#      40203,
#      40230,
#      40231,
#      40232,
#      40209,
#      40210,
#      40211,
#      40212,
#      40213,
#      40214,
#      40215,
#      40216,
#      40217,
#      40236,
#      40237,
#      40238,
#      40221,
#      40222,
#      40223,
#      40218,
#      40219,
#      40220,
#      40227,
#      40228,
#      40229,
#      40224,
#      40225,
#      40226,
#      40275,
#      40276,
#      40277,
#      40272,
#      40273,
#      40305,
#      41436,
#      41437,
#      41438,
#      41442,
#      41443,
#      41444,
#      40278,
#      40279,
#      40280,
#      40287,
#      40288,
#      40289,
#      40281,
#      40282,
#      40283,
#      40328,
#      41022,
#      41023,
#      41024,
#      41025,
#      40330,
#      40329,
#      41259,
#      41260,
#      41263,
#      41264,
#      41267,
#      41268,
#      41600]}],
#   'salesItemIds': [40012, 40206, 40203, 40202, 40205, 40201, 40204]},
#  {'baseImageName': '267',
#   'description': 'A juicy chicken breast marinated and breaded in our unique, fiery blend of peppers and spices to deliver more flavor inside and out, cooled down with crisp lettuce, tomato, and mayo. It’s the original spicy chicken sandwich, and the one you crave.',
#   'displayName': 'Spicy Chicken Sandwich Combo',
#   'name': 'Spicy Chicken Sandwich Combo',
#   'calorieRange': '540-1,150 cal',
#   'comboConfigId': 1,
#   'comboNumber': 6,
#   'defaultItemId': 40013,
#   'menuItemId': 30083,
#   'price': 6.09,
#   'priceRange': '$6.09',
#   'productGroupId': '267',
#   'promoId': 2071,
#   'salesGroups': [{'description': 'Spicy Chicken Sandwich Combo',
#     'displayName': 'Spicy Chicken Sandwich Combo',
#     'name': 'Spicy Chicken Sandwich Combo',
#     'defaultSalesItemId': 40013,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635744711253658135,
#     'salesItemIds': [40013]},
#    {'description': 'Combo Sides',
#     'displayName': 'Side',
#     'name': 'Side',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113329953416,
#     'salesGroupIds': [165,
#      913,
#      217,
#      455,
#      171,
#      175,
#      172,
#      174,
#      176,
#      170,
#      449,
#      1283],
#     'salesItemIds': [40204,
#      40205,
#      40206,
#      41584,
#      40207,
#      41042,
#      40307,
#      40309,
#      40308,
#      40311,
#      40310,
#      40316,
#      40317,
#      40813,
#      40067]},
#    {'description': 'Combo Drinks',
#     'displayName': 'Drink',
#     'name': 'Drink',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113459456365,
#     'salesGroupIds': [181,
#      183,
#      182,
#      184,
#      192,
#      423,
#      194,
#      193,
#      197,
#      195,
#      198,
#      199,
#      830,
#      831,
#      196,
#      200,
#      201,
#      216,
#      205,
#      206,
#      214,
#      215,
#      535,
#      533,
#      534,
#      829],
#     'salesItemIds': [40201,
#      40202,
#      40203,
#      40230,
#      40231,
#      40232,
#      40209,
#      40210,
#      40211,
#      40212,
#      40213,
#      40214,
#      40215,
#      40216,
#      40217,
#      40236,
#      40237,
#      40238,
#      40221,
#      40222,
#      40223,
#      40218,
#      40219,
#      40220,
#      40227,
#      40228,
#      40229,
#      40224,
#      40225,
#      40226,
#      40275,
#      40276,
#      40277,
#      40272,
#      40273,
#      40305,
#      41436,
#      41437,
#      41438,
#      41442,
#      41443,
#      41444,
# ...
#      40237,
#      40238,
#      40221,
#      40222,
#      40223,
#      40218,
#      40219,
#      40220,
#      40227,
#      40228,
#      40229,
#      40224,
#      40225,
#      40226,
#      40275,
#      40276,
#      40277,
#      40272,
#      40273,
#      40305,
#      41436,
#      41437,
#      41438,
#      41442,
#      41443,
#      41444,
#      40278,
#      40279,
#      40280,
#      40287,
#      40288,
#      40289,
#      40281,
#      40282,
#      40283,
#      40328,
#      41022,
#      41023,
#      41024,
#      41025,
#      40330,
#      40329,
#      41259,
#      41260,
#      41263,
#      41264,
#      41267,
#      41268,
#      41600]}]},
#  {'description': 'National',
#   'displayName': '',
#   'name': 'Pretzel Pub Homestyle Chicken Sandwich Combo',
#   'defaultItemId': 41769,
#   'menuItemId': 31174,
#   'price': 8.69,
#   'promoId': 10431,
#   'salesGroups': [{'description': 'Pretzel Pub Chicken Sandwich Combo',
#     'displayName': 'Pretzel Pub Chicken Sandwich Combo',
#     'name': 'Pretzel Pub Chicken Sandwich Combo',
#     'defaultSalesItemId': 41769,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 637201231984280048},
#    {'description': 'Combo Sides',
#     'displayName': 'Side',
#     'name': 'Side',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113329953416,
#     'salesGroupIds': [165,
#      913,
#      217,
#      455,
#      171,
#      175,
#      172,
#      174,
#      176,
#      170,
#      449,
#      1283],
#     'salesItemIds': [40204,
#      40205,
#      40206,
#      41584,
#      40207,
#      41042,
#      40307,
#      40309,
#      40308,
#      40311,
#      40310,
#      40316,
#      40317,
#      40813,
#      40067]},
#    {'description': 'Combo Drinks',
#     'displayName': 'Drink',
#     'name': 'Drink',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113459456365,
#     'salesGroupIds': [181,
#      183,
#      182,
#      184,
#      192,
#      423,
#      194,
#      193,
#      197,
#      195,
#      198,
#      199,
#      830,
#      831,
#      196,
#      200,
#      201,
#      216,
#      205,
#      206,
#      214,
#      215,
#      535,
#      533,
#      534,
#      829],
#     'salesItemIds': [40201,
#      40202,
#      40203,
#      40230,
#      40231,
#      40232,
#      40209,
#      40210,
#      40211,
#      40212,
#      40213,
#      40214,
#      40215,
#      40216,
#      40217,
#      40236,
#      40237,
#      40238,
#      40221,
#      40222,
#      40223,
#      40218,
#      40219,
#      40220,
#      40227,
#      40228,
#      40229,
#      40224,
#      40225,
#      40226,
#      40275,
#      40276,
#      40277,
#      40272,
#      40273,
#      40305,
#      41436,
#      41437,
#      41438,
#      41442,
#      41443,
#      41444,
#      40278,
#      40279,
#      40280,
#      40287,
#      40288,
#      40289,
#      40281,
#      40282,
#      40283,
#      40328,
#      41022,
#      41023,
#      41024,
#      41025,
#      40330,
#      40329,
#      41259,
#      41260,
#      41263,
#      41264,
#      41267,
#      41268,
#      41600]}]},
#  {'description': 'National',
#   'displayName': '',
#   'name': 'Pretzel Pub Spicy Chicken Sandwich Combo',
#   'defaultItemId': 41771,
#   'menuItemId': 31175,
#   'price': 8.69,
#   'promoId': 10435,
#   'salesGroups': [{'description': 'Pretzel Pub Spicy Chicken Sandwich Combo',
#     'displayName': 'Pretzel Pub Spicy Chicken Sandwich Combo',
#     'name': 'Pretzel Pub Spicy Chicken Sandwich Combo',
#     'defaultSalesItemId': 41771,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 637201233500781149},
#    {'description': 'Combo Sides',
#     'displayName': 'Side',
#     'name': 'Side',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113329953416,
#     'salesGroupIds': [165,
#      913,
#      217,
#      455,
#      171,
#      175,
#      172,
#      174,
#      176,
#      170,
#      449,
#      1283],
#     'salesItemIds': [40204,
#      40205,
#      40206,
#      41584,
#      40207,
#      41042,
#      40307,
#      40309,
#      40308,
#      40311,
#      40310,
#      40316,
#      40317,
#      40813,
#      40067]},
#    {'description': 'Combo Drinks',
#     'displayName': 'Drink',
#     'name': 'Drink',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113459456365,
#     'salesGroupIds': [181,
#      183,
#      182,
#      184,
#      192,
#      423,
#      194,
#      193,
#      197,
#      195,
#      198,
#      199,
#      830,
#      831,
#      196,
#      200,
#      201,
#      216,
#      205,
#      206,
#      214,
#      215,
#      535,
#      533,
#      534,
#      829],
#     'salesItemIds': [40201,
#      40202,
#      40203,
#      40230,
#      40231,
#      40232,
#      40209,
#      40210,
#      40211,
#      40212,
#      40213,
#      40214,
#      40215,
#      40216,
#      40217,
#      40236,
#      40237,
#      40238,
#      40221,
#      40222,
#      40223,
#      40218,
#      40219,
#      40220,
#      40227,
#      40228,
#      40229,
#      40224,
#      40225,
#      40226,
#      40275,
#      40276,
#      40277,
#      40272,
#      40273,
#      40305,
#      41436,
#      41437,
#      41438,
#      41442,
#      41443,
#      41444,
#      40278,
#      40279,
#      40280,
#      40287,
#      40288,
#      40289,
#      40281,
#      40282,
#      40283,
#      40328,
#      41022,
#      41023,
#      41024,
#      41025,
#      40330,
#      40329,
#      41259,
#      41260,
#      41263,
#      41264,
#      41267,
#      41268,
#      41600]}]},
#  {'description': 'National',
#   'displayName': '',
#   'name': 'Pretzel Pub Grilled Chicken Sandwich Combo',
#   'defaultItemId': 41772,
#   'menuItemId': 31176,
#   'price': 8.69,
#   'promoId': 10439,
#   'salesGroups': [{'description': 'Pretzel Pub Grilled Chicken Sandwich Combo',
#     'displayName': 'Pretzel Pub Grilled Chicken Sandwich Combo',
#     'name': 'Pretzel Pub Grilled Chicken Sandwich Combo',
#     'defaultSalesItemId': 41772,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 637201234341817978},
#    {'description': 'Combo Sides',
#     'displayName': 'Side',
#     'name': 'Side',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113329953416,
#     'salesGroupIds': [165,
#      913,
#      217,
#      455,
#      171,
#      175,
#      172,
#      174,
#      176,
#      170,
#      449,
#      1283],
#     'salesItemIds': [40204,
#      40205,
#      40206,
#      41584,
#      40207,
#      41042,
#      40307,
#      40309,
#      40308,
#      40311,
#      40310,
#      40316,
#      40317,
#      40813,
#      40067]},
#    {'description': 'Combo Drinks',
#     'displayName': 'Drink',
#     'name': 'Drink',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113459456365,
#     'salesGroupIds': [181,
#      183,
#      182,
#      184,
#      192,
#      423,
#      194,
#      193,
#      197,
#      195,
#      198,
#      199,
#      830,
#      831,
#      196,
#      200,
#      201,
#      216,
#      205,
#      206,
#      214,
#      215,
#      535,
#      533,
#      534,
#      829],
#     'salesItemIds': [40201,
#      40202,
#      40203,
#      40230,
#      40231,
#      40232,
#      40209,
#      40210,
#      40211,
#      40212,
#      40213,
#      40214,
#      40215,
#      40216,
#      40217,
#      40236,
#      40237,
#      40238,
#      40221,
#      40222,
#      40223,
#      40218,
#      40219,
#      40220,
#      40227,
#      40228,
#      40229,
#      40224,
#      40225,
#      40226,
#      40275,
#      40276,
#      40277,
#      40272,
#      40273,
#      40305,
#      41436,
#      41437,
#      41438,
#      41442,
#      41443,
#      41444,
#      40278,
#      40279,
#      40280,
#      40287,
#      40288,
#      40289,
#      40281,
#      40282,
#      40283,
#      40328,
#      41022,
#      41023,
#      41024,
#      41025,
#      40330,
#      40329,
#      41259,
#      41260,
#      41263,
#      41264,
#      41267,
#      41268,
#      41600]}]},
#  {'description': 'National',
#   'displayName': '',
#   'name': 'Pretzel Pub Chicken Sandwich Combos',
#   'defaultItemId': 41769,
#   'menuItemId': 31177,
#   'price': 8.69,
#   'promoId': 10431,
#   'salesGroups': [{'description': 'Pretzel Pub Chicken Sandwich Combos',
#     'displayName': 'Pretzel Pub Chicken Sandwich Combos',
#     'name': 'Pretzel Pub Chicken Sandwich Combos',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 637201235987359100},
#    {'description': 'Combo Sides',
#     'displayName': 'Side',
#     'name': 'Side',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113329953416,
#     'salesGroupIds': [165,
#      913,
#      217,
#      455,
#      171,
#      175,
#      172,
#      174,
#      176,
#      170,
#      449,
#      1283],
#     'salesItemIds': [40204,
#      40205,
#      40206,
#      41584,
#      40207,
#      41042,
#      40307,
#      40309,
#      40308,
#      40311,
#      40310,
#      40316,
#      40317,
#      40813,
#      40067]},
#    {'description': 'Combo Drinks',
#     'displayName': 'Drink',
#     'name': 'Drink',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113459456365,
#     'salesGroupIds': [181,
#      183,
#      182,
#      184,
#      192,
#      423,
#      194,
#      193,
#      197,
#      195,
#      198,
#      199,
#      830,
#      831,
#      196,
#      200,
#      201,
#      216,
#      205,
#      206,
#      214,
#      215,
#      535,
#      533,
#      534,
#      829],
#     'salesItemIds': [40201,
#      40202,
#      40203,
#      40230,
#      40231,
#      40232,
#      40209,
#      40210,
#      40211,
#      40212,
#      40213,
#      40214,
#      40215,
#      40216,
#      40217,
#      40236,
#      40237,
#      40238,
#      40221,
#      40222,
#      40223,
#      40218,
#      40219,
#      40220,
#      40227,
#      40228,
#      40229,
#      40224,
#      40225,
#      40226,
#      40275,
#      40276,
#      40277,
#      40272,
#      40273,
#      40305,
#      41436,
#      41437,
#      41438,
#      41442,
#      41443,
#      41444,
#      40278,
#      40279,
#      40280,
#      40287,
#      40288,
#      40289,
#      40281,
#      40282,
#      40283,
#      40328,
#      41022,
#      41023,
#      41024,
#      41025,
#      40330,
#      40329,
#      41259,
#      41260,
#      41263,
#      41264,
#      41267,
#      41268,
#      41600]}]},
#  {'description': '',
#   'displayName': '',
#   'name': "Wendy's Digital",
#   'defaultItemId': 41773,
#   'menuItemId': 31179,
#   'price': 0.0,
#   'promoId': 0},
#  {'baseImageName': '1237',
#   'description': 'A juicy chicken breast marinated and breaded in our unique, fiery blend of peppers and spices to deliver more flavor inside and out, cooled down with crisp lettuce, tomato, and mayo. It’s the original spicy chicken sandwich, and the one you crave.',
#   'displayName': '2 Spicy Chickens, 2 JBCs & 4 SM Fries',
#   'name': 'Family Meal Spicy Chicken',
#   'defaultItemId': 41777,
#   'menuItemId': 31181,
#   'price': 15.0,
#   'priceRange': '$15.00',
#   'productGroupId': '1237',
#   'promoId': 10461,
#   'salesGroups': [{'description': 'Spicy Chicken Sandwich',
#     'displayName': 'Spicy Chicken Sandwich',
#     'name': 'Spicy Chicken Sandwich',
#     'defaultSalesItemId': 41777,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 637220423471328814,
#     'salesItemIds': [41777]},
#    {'description': 'Spicy Chicken Sandwich',
#     'displayName': 'Spicy Chicken Sandwich',
#     'name': 'Spicy Chicken Sandwich',
#     'defaultSalesItemId': 41777,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 637220424464958177,
#     'salesItemIds': [41777]},
#    {'description': 'Jr. Bacon Cheeseburger',
#     'displayName': 'Jr. Bacon Cheeseburger',
#     'name': 'Jr. Bacon Cheeseburger',
#     'defaultSalesItemId': 41774,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 637220427734188916,
#     'salesItemIds': [41774]},
#    {'description': 'Jr. Bacon Cheeseburger',
#     'displayName': 'Jr. Bacon Cheeseburger',
#     'name': 'Jr. Bacon Cheeseburger',
#     'defaultSalesItemId': 41774,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 637220428019864254,
#     'salesItemIds': [41774]},
#    {'description': 'Small Fries',
#     'displayName': 'Small Fries',
#     'name': 'Small Fries',
#     'defaultSalesItemId': 41775,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 637220428349652883,
#     'salesItemIds': [41775]},
#    {'description': 'Small Fries',
#     'displayName': 'Small Fries',
#     'name': 'Small Fries',
#     'defaultSalesItemId': 41775,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 637220429662549014,
#     'salesItemIds': [41775]},
#    {'description': 'Small Fries',
#     'displayName': 'Small Fries',
#     'name': 'Small Fries',
#     'defaultSalesItemId': 41775,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 637220429785663201,
#     'salesItemIds': [41775]},
#    {'description': 'Small Fries',
#     'displayName': 'Small Fries',
#     'name': 'Small Fries',
#     'defaultSalesItemId': 41775,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 637220429901687452,
#     'salesItemIds': [41775]}],
#   'salesItemIds': [41777, 41774, 41775]},
#  {'baseImageName': '433',
#   'description': 'Made fresh daily with our Wendy’s signature lettuce blend, herb-marinated grilled chicken breast, a three-cheese blend of Parmesan, Asiago, and Fontina, Applewood smoked bacon, and, of course, strawberries. All topped with candied almonds and Marzetti®¿ Simply Dressed® Champagne Vinaigrette. Raise a glass because this tasty of a salad deserves a toast.',
#   'displayName': 'Summer Strawberry Salad',
#   'name': 'Summer Strawberry Chicken Salad',
#   'calorieRange': '290/530 cal',
#   'defaultItemId': 41781,
#   'menuItemId': 31184,
#   'price': 0.0,
#   'priceRange': '$5.19/$7.19',
#   'productGroupId': '433',
#   'promoId': 0,
#   'salesItemIds': [41781, 41782]},
#  {'description': 'Juicy white meat, lightly breaded and seasoned, topped with crisp lettuce, and mayo. More than delicious, and just the right size.',
#   'displayName': 'Crispy Chicken Sandwich - Biggie Bag',
#   'name': 'Crispy Chicken Sandwich - Biggie Bag',
#   'defaultItemId': 40016,
#   'menuItemId': 31185,
#   'price': 5.0,
#   'priceRange': '$5.00',
#   'productGroupId': '338',
#   'promoId': 6972,
#   'salesGroups': [{'description': 'Crispy Chicken Sandwich - Biggie Bag',
#     'displayName': 'Crispy Chicken Sandwich - Biggie Bag',
#     'name': 'Crispy Chicken Sandwich - Biggie Bag',
#     'defaultSalesItemId': 40016,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 637243096771360959,
#     'salesItemIds': [40016]},
#    {'description': 'Nuggets',
#     'displayName': 'Nuggets',
#     'name': 'Nuggets',
#     'defaultSalesItemId': 40024,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 637243098631649385,
#     'salesGroupIds': [10000000000136, 10000000000137],
#     'salesItemIds': [40024, 40181]},
#    {'description': 'Combo Drinks',
#     'displayName': 'Fries',
#     'name': 'Fries',
#     'defaultSalesItemId': 40659,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635931389501442760,
#     'salesGroupIds': [10000000000133, 10000000000134, 10000000000135],
#     'salesItemIds': [40204, 40798, 40799]},
#    {'description': 'Combo Drinks',
#     'displayName': 'Drink',
#     'name': 'Drink',
#     'defaultSalesItemId': 0,
#     'maximumItems': 1,
#     'minimumItems': 1,
#     'salesGroupId': 635761113459456365,
#     'salesGroupIds': [181,
#      183,
#      182,
#      184,
#      192,
#      423,
#      194,
#      193,
#      197,
#      195,
#      198,
#      199,
#      830,
#      831,
#      196,
#      200,
#      201,
#      216,
#      205,
#      206,
#      214,
#      215,
#      535,
#      533,
#      534,
#      829],
#     'salesItemIds': [40201,
#      40202,
#      40203,
#      40230,
#      40231,
#      40232,
#      40209,
#      40210,
#      40211,
#      40212,
#      40213,
#      40214,
#      40215,
#      40216,
#      40217,
#      40236,
#      40237,
#      40238,
#      40221,
#      40222,
#      40223,
#      40218,
#      40219,
#      40220,
#      40227,
#      40228,
#      40229,
#      40224,
#      40225,
#      40226,
#      40275,
#      40276,
#      40277,
#      40272,
#      40273,
#      40305,
#      41436,
#      41437,
#      41438,
#      41442,
#      41443,
#      41444,
#      40278,
#      40279,
#      40280,
#      40287,
#      40288,
#      40289,
#      40281,
#      40282,
#      40283,
#      40328,
#      41022,
#      41023,
#      41024,
#      41025,
#      40330,
#      40329,
#      41259,
#      41260,
#      41263,
#      41264,
#      41267,
#      41268,
#      41600]}],
#   'salesItemIds': [40016]}]

# %%
salesItems=menuog["menuLists"]["salesItems"]
modifiers=menuog["menuLists"]["modifiers"]

# %%
menu=[]

# %%
for i in range (0, len(menuItems)):
    try:
        item={"ID": menuItems[i]["menuItemId"],"nImmagine":menuItems[i]["baseImageName"],\
       "descrizione": menuItems[i]["description"], "nome": menuItems[i]["displayName"],\
       "calorie":menuItems[i]["calorieRange"],\
        "prezzo":menuItems[i]["priceRange"], "fk":menuItems[i]["defaultItemId"]}
        menu.append(item)
    except KeyError: pass

# %%
len(menu)
# Out:
# 158

# %%
for i in range (0, len(menu)):
    try:
        IDsale=menu[i]["fk"]
        item=[itemS for itemS in salesItems if itemS["salesItemId"]==IDsale][0]
        menu[i]["categoria"]=item["categoryName"]
        menu[i]["ingredienti"]=[ingrediente["modifierId"] for ingrediente in item["defaultOptions"]]
        del(menu[i]["fk"])
    except KeyError: pass

# %%
menu
# Out:
# [{'ID': 30000,
#   'nImmagine': '141',
#   'descrizione': 'A quarter-pound* of fresh beef, American cheese, crisp lettuce, tomato, pickle, ketchup, mayo, and onion on a toasted bun — just the way Dave intended.',
#   'nome': "Dave's Single®",
#   'calorie': '570 cal',
#   'prezzo': '$3.49',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197,
#    70214,
#    70215,
#    71567,
#    71570,
#    71569,
#    71571,
#    71539,
#    70222]},
#  {'ID': 30001,
#   'nImmagine': '142',
#   'descrizione': 'A half-pound* of fresh beef, American cheese, crisp lettuce, tomato, pickle, ketchup, mayo, and onion on a toasted bun. More meat means more to love.  ',
#   'nome': "Dave's Double®",
#   'calorie': '810 cal',
#   'prezzo': '$4.59',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197,
#    70214,
#    70215,
#    71567,
#    71570,
#    71569,
#    71571,
#    71539,
#    71151]},
#  {'ID': 30002,
#   'nImmagine': '143',
#   'descrizione': 'Three quarters of a pound* of fresh, never frozen beef, American cheese, crisp lettuce, tomato, pickle, ketchup, mayo, and onion on a toasted bun. Use both hands!',
#   'nome': "Dave's Triple®",
#   'calorie': '1,100 cal',
#   'prezzo': '$5.49',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197,
#    70214,
#    70215,
#    71567,
#    71569,
#    71571,
#    71570,
#    71557,
#    71152]},
#  {'ID': 30003,
#   'nImmagine': '144',
#   'descrizione': 'A half-pound* of fresh beef, American cheese, 6 pieces of crispy Applewood smoked bacon, ketchup, and mayo. Carnivores rejoice!',
#   'nome': 'Baconator®',
#   'calorie': '920 cal',
#   'prezzo': '$5.89',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197, 70214, 70215, 71151, 71179, 71539]},
#  {'ID': 30004,
#   'nImmagine': '145',
#   'descrizione': 'A quarter-pound of fresh beef, American cheese, plenty of Applewood smoked bacon, ketchup, and mayo. Like Baconator®, like Son. ',
#   'nome': 'Son of Baconator®',
#   'calorie': '630 cal',
#   'prezzo': '$4.19',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197, 70214, 70215, 71539, 71156, 71565]},
#  {'ID': 30005,
#   'nImmagine': '146',
#   'descrizione': 'Two patties of fresh, never frozen beef with cheese, ketchup, mustard, pickle, and onion. It’s double the fresh beef, stacked with deliciousness.',
#   'nome': 'Double Stack™',
#   'calorie': '390 cal',
#   'prezzo': '$1.79',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70201, 70205, 71530, 71527, 71610, 71611, 71156]},
#  {'ID': 30006,
#   'nImmagine': '147',
#   'descrizione': 'Fresh beef, Applewood smoked bacon, American cheese, crisp lettuce, tomato, and mayo. It’s a favorite of bacon lovers everywhere.',
#   'nome': 'Jr. Bacon Cheeseburger',
#   'calorie': '380 cal',
#   'prezzo': '$1.60',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70201, 70205, 71526, 71609, 71612, 71154, 71048]},
#  {'ID': 30007,
#   'nImmagine': '148',
#   'descrizione': 'Fresh beef topped with cheese, pickles, onions, tomatoes, crisp lettuce, ketchup, and mayo. It’s big flavor at a junior price. ',
#   'nome': 'Jr. Cheeseburger Deluxe',
#   'calorie': '340 cal',
#   'prezzo': '$1.19',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70201,
#    70205,
#    71530,
#    71526,
#    71609,
#    71610,
#    71611,
#    71612,
#    71048]},
#  {'ID': 30008,
#   'nImmagine': '149',
#   'descrizione': 'Fresh beef topped with cheese, pickles, onion, ketchup, and mustard on a toasted bun. It’s done just right, and just the right size.',
#   'nome': 'Jr. Cheeseburger',
#   'calorie': '280 cal',
#   'prezzo': '$0.99',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70201, 70205, 71530, 71527, 71610, 71611, 71048]},
#  {'ID': 30009,
#   'nImmagine': '150',
#   'descrizione': 'Fresh beef topped with pickles, onion, ketchup, and mustard on a toasted bun. It’s done just right, and just the right size.',
#   'nome': 'Jr. Hamburger',
#   'calorie': '240 cal',
#   'prezzo': '$0.99',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70201, 71530, 71527, 71610, 71611, 71048]},
#  {'ID': 30010,
#   'nImmagine': '167',
#   'descrizione': 'A sizzling chicken breast grilled to perfection, with thick Applewood smoked bacon, Asiago cheese, creamy ranch sauce, crisp lettuce, and tomato, all on a toasted bun. Go grilled. Go home happy.',
#   'nome': 'Grilled Asiago Ranch Club',
#   'calorie': '500 cal',
#   'prezzo': '$4.79',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70197, 70206, 70217, 71567, 71571, 71032, 71507]},
#  {'ID': 30011,
#   'nImmagine': '156',
#   'descrizione': 'A juicy, lightly breaded chicken breast taken over the top with thick Applewood smoked bacon, Asiago cheese, creamy ranch sauce, crisp lettuce, and tomato, all on a toasted bun. A club favorite that’s anything but boring.',
#   'nome': 'Homestyle Asiago Ranch Chicken Club',
#   'calorie': '640 cal',
#   'prezzo': '$4.82',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70197, 70206, 70217, 71567, 71571, 71032, 71508]},
#  {'ID': 30012,
#   'nImmagine': '166',
#   'descrizione': 'A juicy chicken breast marinated and breaded in our unique, fiery blend of peppers and spices to deliver more flavor inside and out, topped with thick Applewood smoked bacon, Asiago cheese, creamy ranch sauce, crisp lettuce, and tomato, all on a toasted bun. So hot you’ll wanna give your mouth a heads up. ',
#   'nome': 'Spicy Asiago Ranch Club',
#   'calorie': '630 cal',
#   'prezzo': '$4.79',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70197, 70206, 70217, 71567, 71571, 71032, 71620]},
#  {'ID': 30013,
#   'nImmagine': '151',
#   'descrizione': 'A juicy chicken breast marinated and breaded in our unique, fiery blend of peppers and spices to deliver more flavor inside and out, cooled down with crisp lettuce, tomato, and mayo. It’s the original spicy chicken sandwich, and the one you crave.',
#   'nome': 'Spicy Chicken Sandwich',
#   'calorie': '500 cal',
#   'prezzo': '$4.39',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70197, 70215, 71567, 71571, 71620]},
#  {'ID': 30014,
#   'nImmagine': '153',
#   'descrizione': 'A juicy, lightly-breaded chicken breast, crisp lettuce and tomato, and just enough mayo, all on a toasted bun. It’s extra comfy comfort food.',
#   'nome': 'Homestyle Chicken Sandwich',
#   'calorie': '500 cal',
#   'prezzo': '$4.39',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70197, 70215, 71567, 71571, 71508]},
#  {'ID': 30016,
#   'nImmagine': '155',
#   'descrizione': 'Juicy white meat, lightly breaded and seasoned, topped with crisp lettuce, and mayo. More than delicious, and just the right size.',
#   'nome': 'Crispy Chicken Sandwich',
#   'calorie': '330 cal',
#   'prezzo': '$0.99',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70201, 71526, 71609, 71050]},
#  {'ID': 30021,
#   'nImmagine': '942',
#   'descrizione': '100% white-meat chicken breaded and marinated in our unique, fiery blend of peppers and spices. Served with your choice of six dipping sauces including Buttermilk Ranch, Creamy Sriracha, BBQ, Sweet & Sour, Honey Mustard or Side of S’Awesome®. The Internet icon is back for a hot minute.',
#   'nome': '4 PC. Spicy Chicken Nuggets',
#   'calorie': '190 cal',
#   'prezzo': '$0.99',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [72115]},
#  {'ID': 30023,
#   'nImmagine': '943',
#   'descrizione': '100% white-meat chicken breaded and marinated in our unique, fiery blend of peppers and spices. Served with your choice of six dipping sauces including Buttermilk Ranch, Creamy Sriracha, BBQ, Sweet & Sour, Honey Mustard or Side of S’Awesome®. The Internet icon is back for a hot minute.',
#   'nome': '6 PC. Spicy Chicken Nuggets',
#   'calorie': '280 cal',
#   'prezzo': '$1.49',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [71158]},
#  {'ID': 30024,
#   'nImmagine': '727',
#   'descrizione': '100% white-meat chicken breaded to crispy perfection and served with your choice of 6 dipping sauces including Buttermilk Ranch, Creamy Sriracha, BBQ, Sweet & Sour, Honey Mustard, or Side of S’Awesome®. They’re trending in our restaurants and Twitter feed alike.',
#   'nome': '10 PC. Crispy Chicken Nuggets',
#   'calorie': '420 cal',
#   'prezzo': '$4.69',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [71160]},
#  {'ID': 30027,
#   'nImmagine': '161',
#   'descrizione': 'Made fresh daily with Wendy’s signature lettuce blend, crisp red and green apples, dried cranberries, roasted pecans, crumbled blue cheese, and grilled chicken breast hot off the grill, all topped with Marzetti® Simply Dressed® Pomegranate Vinaigrette. An unbeatable pick.\r\n\r\nNutrition and allergen information is inclusive of all ingredients in this salad including two packets of dressing on the full-size salad and one packet on the half, which come on the side.\r\n',
#   'nome': 'Apple Pecan Chicken Salad',
#   'calorie': '340/570 cal',
#   'prezzo': '$4.09/$6.09',
#   'categoria': 'Fresh-Made Salads',
#   'ingredienti': [71045, 70739, 71172, 71555, 70953]},
#  {'ID': 30028,
#   'nImmagine': '833',
#   'descrizione': 'Made fresh daily with romaine lettuce, grilled chicken breast, Italian cheeses, crunchy Parmesan crisps, and creamy Caesar dressing. One bite will tell you why it’s king of more than just the Romaines.',
#   'nome': 'Parmesan Caesar Chicken Salad',
#   'calorie': '310/560 cal',
#   'prezzo': '$4.79/$6.79',
#   'categoria': 'Fresh-Made Salads',
#   'ingredienti': [71555, 71150, 71865, 71877]},
#  {'ID': 30032,
#   'nImmagine': '165',
#   'descrizione': 'Natural-cut, skin-on, sea-salted fries served hot and crispy. The world loves them for a reason.',
#   'nome': 'French Fries',
#   'calorie': '220-480 cal',
#   'prezzo': '$0.99-$1.99',
#   'categoria': 'Fries & Sides',
#   'ingredienti': [71183, 71662]},
#  {'ID': 30036,
#   'nImmagine': '170',
#   'descrizione': 'Perfectly seasoned and positively irresistible. Red’s kind of our thing, you know.',
#   'nome': 'Chili',
#   'calorie': '240/330 cal',
#   'prezzo': '$1.79/$2.49',
#   'categoria': 'Fries & Sides',
#   'ingredienti': [71187]},
#  {'ID': 30038,
#   'nImmagine': '1283',
#   'descrizione': 'Strawberries served ripe and chilled. It’s a burst of summer flavor whenever you want them.',
#   'nome': 'Strawberries',
#   'calorie': '20 cal',
#   'prezzo': '$1.79',
#   'categoria': 'Fries & Sides',
#   'ingredienti': [71763]},
#  {'ID': 30039,
#   'nImmagine': '217',
#   'descrizione': 'Our natural-cut, skin-on, sea-salted fries topped with warm, creamy cheese sauce, shredded cheddar, and crispy Applewood smoked bacon. The only fries worthy of the Baconator name.',
#   'nome': 'Baconator Fries',
#   'calorie': '470 cal',
#   'prezzo': '$1.99',
#   'categoria': 'Fries & Sides',
#   'ingredienti': [70382, 70380, 70381, 71543]},
#  {'ID': 30047,
#   'nImmagine': '205',
#   'descrizione': 'A blend of 100% Arabica beans from central and south America, medium-roasted to bring out all the best flavors.',
#   'nome': 'Fresh Brewed Coffee',
#   'calorie': '5 cal',
#   'prezzo': '$0.99/$1.29',
#   'categoria': 'Beverages',
#   'ingredienti': [71844]},
#  {'ID': 30048,
#   'nImmagine': '206',
#   'descrizione': 'Brewed to be rich and smooth without the caffeine. ',
#   'nome': 'Fresh Brewed Decaffeinated Coffee',
#   'calorie': '0 cal',
#   'prezzo': '$0.99/$1.29',
#   'fk': 40445,
#   'categoria': 'Beverages'},
#  {'ID': 30050,
#   'nImmagine': '214',
#   'descrizione': '1% milk with 30% of the daily calcium requirement.',
#   'nome': 'Milk',
#   'calorie': '90 cal',
#   'prezzo': '$1.29',
#   'categoria': 'Beverages',
#   'ingredienti': [71798]},
#  {'ID': 30051,
#   'nImmagine': '215',
#   'descrizione': 'A favorite since forever with 25% the daily calcium requirement.',
#   'nome': 'Chocolate Milk',
#   'calorie': '140 cal',
#   'prezzo': '$1.29',
#   'categoria': 'Beverages',
#   'ingredienti': [71799]},
#  {'ID': 30053,
#   'nImmagine': '179',
#   'descrizione': 'The Chocolate Frosty® was born out of Dave’s desire for a signature dessert to go with his vision of the perfect meal. Thick enough to use a spoon, smooth enough to use a straw, and perfect when enjoyed on the end of a fry. ',
#   'nome': 'Classic Chocolate Frosty®',
#   'calorie': '200-590 cal',
#   'prezzo': '$0.89-$1.89',
#   'categoria': 'Frosty',
#   'ingredienti': [71702]},
#  {'ID': 30054,
#   'nImmagine': '180',
#   'descrizione': 'The vanilla version of our signature frozen dessert. Cool and creamy don’t do it justice. This is the smooth, thick, sweet dessert masterpiece that goes with everything on our menu. You deserve a dessert this good, so go ahead.',
#   'nome': 'Vanilla Frosty®',
#   'calorie': '190-570 cal',
#   'prezzo': '$0.89-$1.89',
#   'categoria': 'Frosty',
#   'ingredienti': [71698]},
#  {'ID': 30057,
#   'nImmagine': '581',
#   'descrizione': 'Give yourself a wholesome start to the day with our Fresh Baked Oatmeal Bar made with whole oats, sweet blueberries and tart cranberries.\r\n',
#   'nome': 'Oatmeal Bar',
#   'calorie': '270 cal',
#   'prezzo': '$1.39',
#   'categoria': 'Bakery',
#   'ingredienti': [71837]},
#  {'ID': 30058,
#   'nImmagine': '451',
#   'descrizione': 'A rich, soft, fresh-baked cookie full of semi-sweet chunks of chocolate, baked in-house. Grandma would love them.',
#   'nome': 'Chocolate Chunk Cookie',
#   'calorie': '330 cal',
#   'prezzo': '$1.39',
#   'categoria': 'Bakery',
#   'ingredienti': [71715]},
#  {'ID': 30059,
#   'nImmagine': '453',
#   'descrizione': 'The traditional favorite. Soft, fresh-baked, simple, and perfect.',
#   'nome': 'Sugar Cookie',
#   'calorie': '330 cal',
#   'prezzo': '$1.39',
#   'categoria': 'Bakery',
#   'ingredienti': [71716]},
#  {'ID': 30060,
#   'nImmagine': '452',
#   'descrizione': 'A soft, fresh-baked chocolate cookie with chocolate chunks, baked in-house. Chocolate and chocolate, together at last.',
#   'nome': 'Double Chocolate Chip Cookie',
#   'calorie': '290 cal',
#   'prezzo': '$1.39',
#   'categoria': 'Bakery',
#   'ingredienti': [71714]},
#  {'ID': 30071,
#   'nImmagine': '263',
#   'descrizione': 'A half-pound* of fresh beef, American cheese, crisp lettuce, tomato, pickle, ketchup, mayo, and onion on a toasted bun. More meat means more to love.  ',
#   'nome': "Dave's Double®",
#   'calorie': '850-1,460 cal',
#   'prezzo': '$6.49',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197,
#    70214,
#    70215,
#    71567,
#    71570,
#    71569,
#    71571,
#    71539,
#    71151]},
#  {'ID': 30072,
#   'nImmagine': '264',
#   'descrizione': 'Three quarters of a pound* of fresh, never frozen beef, American cheese, crisp lettuce, tomato, pickle, ketchup, mayo, and onion on a toasted bun. Use both hands!',
#   'nome': "Dave's Triple®",
#   'calorie': '1,130-1,740 cal',
#   'prezzo': '$7.59',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197,
#    70214,
#    70215,
#    71567,
#    71569,
#    71571,
#    71570,
#    71557,
#    71152]},
#  {'ID': 30073,
#   'nImmagine': '265',
#   'descrizione': 'A half-pound* of fresh beef, American cheese, 6 pieces of crispy Applewood smoked bacon, ketchup, and mayo. Carnivores rejoice!',
#   'nome': 'Baconator®',
#   'calorie': '980-1,600 cal',
#   'prezzo': '$7.99',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197, 70214, 70215, 71151, 71179, 71539]},
#  {'ID': 30074,
#   'nImmagine': '266',
#   'descrizione': 'A quarter-pound of fresh beef, American cheese, plenty of Applewood smoked bacon, ketchup, and mayo. Like Baconator®, like Son. ',
#   'nome': 'Son of Baconator®',
#   'calorie': '670-1,280 cal',
#   'prezzo': '$6.09',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197, 70214, 70215, 71539, 71156, 71565]},
#  {'ID': 30080,
#   'nImmagine': '666',
#   'descrizione': 'A sizzling chicken breast grilled to perfection, with thick Applewood smoked bacon, Asiago cheese, creamy ranch sauce, crisp lettuce, and tomato, all on a toasted bun. Go grilled. Go home happy.',
#   'nome': 'Grilled Asiago Ranch Chicken Club',
#   'calorie': '560-1,180 cal',
#   'prezzo': '$6.79',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70197, 70206, 70217, 71567, 71571, 71032, 71507]},
#  {'ID': 30081,
#   'nImmagine': '598',
#   'descrizione': 'A juicy, lightly breaded chicken breast taken over the top with thick Applewood smoked bacon, Asiago cheese, creamy ranch sauce, crisp lettuce, and tomato, all on a toasted bun. A club favorite that’s anything but boring.',
#   'nome': 'Homestyle  Asiago Ranch Chicken Club',
#   'calorie': '700-1,320 cal',
#   'prezzo': '$6.79',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70197, 70206, 70217, 71567, 71571, 71032, 71508]},
#  {'ID': 30082,
#   'nImmagine': '599',
#   'descrizione': 'A juicy chicken breast marinated and breaded in our unique, fiery blend of peppers and spices to deliver more flavor inside and out, topped with thick Applewood smoked bacon, Asiago cheese, creamy ranch sauce, crisp lettuce, and tomato, all on a toasted bun. So hot you’ll wanna give your mouth a heads up. ',
#   'nome': 'Spicy Asiago Ranch Chicken Club',
#   'calorie': '710-1,320 cal',
#   'prezzo': '$6.79',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70197, 70206, 70217, 71567, 71571, 71032, 71620]},
#  {'ID': 30083,
#   'nImmagine': '267',
#   'descrizione': 'A juicy chicken breast marinated and breaded in our unique, fiery blend of peppers and spices to deliver more flavor inside and out, cooled down with crisp lettuce, tomato, and mayo. It’s the original spicy chicken sandwich, and the one you crave.',
#   'nome': 'Spicy Chicken Sandwich Combo',
#   'calorie': '540-1,150 cal',
#   'prezzo': '$6.09',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70197, 70215, 71567, 71571, 71620]},
#  {'ID': 30084,
#   'nImmagine': '268',
#   'descrizione': 'A juicy, lightly-breaded chicken breast, crisp lettuce and tomato, and just enough mayo, all on a toasted bun. It’s extra comfy comfort food.',
#   'nome': 'Homestyle Chicken Sandwich Combo',
#   'calorie': '540-1,150 cal',
#   'prezzo': '$5.89',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70197, 70215, 71567, 71571, 71508]},
#  {'ID': 30094,
#   'nImmagine': '271',
#   'descrizione': '100% white-meat chicken breaded to crispy perfection and served with your choice of 6 dipping sauces including Buttermilk Ranch, Creamy Sriracha, BBQ, Sweet & Sour, Honey Mustard, or Side of S’Awesome®. They’re trending in our restaurants and Twitter feed alike.',
#   'nome': '10 PC. Nuggets Combo',
#   'calorie': '540-1,260 cal',
#   'prezzo': '$5.39',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [71160]},
#  {'ID': 30095,
#   'nImmagine': '944',
#   'descrizione': '100% white-meat chicken breaded and marinated in our unique, fiery blend of peppers and spices. Served with your choice of six dipping sauces including Buttermilk Ranch, Creamy Sriracha, BBQ, Sweet & Sour, Honey Mustard or Side of S’Awesome®. The Internet icon is back for a hot minute.',
#   'nome': '10 PC. Spicy Chicken Nugget',
#   'calorie': '470 cal',
#   'prezzo': '$4.69',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [71157]},
#  {'ID': 30104,
#   'nImmagine': '171',
#   'descrizione': 'Hot and fluffy potato topped with creamy cheese sauce, shredded cheese, and Applewood smoked bacon. Because nothing goes with a potato like cheese, more cheese, and also bacon.',
#   'nome': 'Bacon Cheese Baked Potato',
#   'calorie': '440 cal',
#   'prezzo': '$2.60',
#   'categoria': 'Fries & Sides',
#   'ingredienti': [70404, 70403, 71178, 70401]},
#  {'ID': 30105,
#   'nImmagine': '172',
#   'descrizione': 'Hot and fluffy potato with shredded cheddar cheese and rich, creamy cheese sauce on top. It’s savory and delicious no matter how you skin it. ',
#   'nome': 'Cheese Baked Potato',
#   'calorie': '450 cal',
#   'prezzo': '$2.50',
#   'categoria': 'Fries & Sides',
#   'ingredienti': [70403, 70401, 71178]},
#  {'ID': 30106,
#   'nImmagine': '175',
#   'descrizione': 'Hot and fluffy potato topped with Wendy’s signature meaty, flavorful chili, rich, creamy cheese sauce, and shredded cheddar. This spud’s your best bud. ',
#   'nome': 'Chili & Cheese Baked Potato',
#   'calorie': '500 cal',
#   'prezzo': '$2.60',
#   'categoria': 'Fries & Sides',
#   'ingredienti': [70403, 70402, 70401, 71178]},
#  {'ID': 30107,
#   'nImmagine': '174',
#   'descrizione': 'A hot, fluffy potato topped with the classic combination of chives, and sour cream. It’s a side, it’s a meal, it’s a potato’s potato. Potato. ',
#   'nome': 'Sour Cream and Chive Baked Potato',
#   'calorie': '310 cal',
#   'prezzo': '$0.99',
#   'categoria': 'Fries & Sides',
#   'ingredienti': [70398, 71178, 70396]},
#  {'ID': 30276,
#   'nImmagine': '187',
#   'descrizione': 'Fresh, never frozen beef hot off the grill and topped with ketchup, just the way your child wants it. It’s what every kid deserves.',
#   'nome': "Kids' Hamburger",
#   'calorie': '270-610 cal',
#   'prezzo': '$2.99',
#   'fk': 40643},
#  {'ID': 30277,
#   'nImmagine': '181',
#   'descrizione': 'The cold, refreshing, sparkling classic that America loves. ',
#   'nome': 'Coca-Cola®',
#   'calorie': '200-400 cal',
#   'prezzo': '$1.59-$1.99',
#   'fk': 40365,
#   'categoria': 'Beverages'},
#  {'ID': 30278,
#   'nImmagine': '182',
#   'descrizione': 'The great taste of Coca-Cola® with zero calories.',
#   'nome': 'Diet Coke®',
#   'calorie': '0 cal',
#   'prezzo': '$1.59-$1.99',
#   'fk': 40369,
#   'categoria': 'Beverages'},
#  {'ID': 30279,
#   'nImmagine': '192',
#   'descrizione': 'A signature blend of 23 flavors makes it truly unique.',
#   'nome': 'Dr Pepper®',
#   'calorie': '120-240 cal',
#   'prezzo': '$1.59-$1.99',
#   'fk': 40373,
#   'categoria': 'Beverages'},
#  {'ID': 30280,
#   'nImmagine': '184',
#   'descrizione': 'The cold, refreshing flavors of lemon and lime, perfectly blended.',
#   'nome': 'Sprite®',
#   'calorie': '200-390 cal',
#   'prezzo': '$1.59-$1.99',
#   'fk': 40377,
#   'categoria': 'Beverages'},
#  {'ID': 30281,
#   'nImmagine': '193',
#   'descrizione': 'Change up your routine with the bright, bubbly, fruity flavor of Fanta® Orange.',
#   'nome': 'Fanta® Orange',
#   'calorie': '210-430 cal',
#   'prezzo': '$1.59-$1.99',
#   'fk': 40381,
#   'categoria': 'Beverages'},
#  {'ID': 30282,
#   'nImmagine': '195',
#   'descrizione': 'Explosive fruit flavors and 100% of the vitamin C your body needs.',
#   'nome': "Hi-C® Flashin' Fruit Punch®",
#   'calorie': '210-420 cal',
#   'prezzo': '$1.59-$1.99',
#   'fk': 40385,
#   'categoria': 'Beverages'},
#  {'ID': 30283,
#   'nImmagine': '196',
#   'descrizione': 'Real lemonade with no artificial ingredients or preservatives.',
#   'nome': 'All-Natural Lemonade',
#   'calorie': '190-380 cal',
#   'prezzo': '$1.79-$2.49',
#   'categoria': 'Beverages',
#   'ingredienti': [71664]},
#  {'ID': 30284,
#   'nImmagine': '197',
#   'descrizione': 'A lighter take on the sweet, tart American classic.',
#   'nome': 'Minute Maid® Light Lemonade',
#   'calorie': '5-15 cal',
#   'prezzo': '$1.59-$1.99',
#   'fk': 40393,
#   'categoria': 'Beverages'},
#  {'ID': 30285,
#   'nImmagine': '198',
#   'descrizione': 'Brewed to perfection, cool and refreshing any time.',
#   'nome': 'Iced Tea',
#   'calorie': '0-5 cal',
#   'prezzo': '$1.59-$1.99',
#   'categoria': 'Beverages',
#   'ingredienti': [71849]},
#  {'ID': 30286,
#   'nImmagine': '199',
#   'descrizione': 'Brewed perfectly and sweetened just the way you like it.',
#   'nome': 'Sweet Iced Tea',
#   'calorie': '160-300 cal',
#   'prezzo': '$1.59-$1.99',
#   'categoria': 'Beverages',
#   'ingredienti': [71853]},
#  {'ID': 30287,
#   'nImmagine': '200',
#   'descrizione': 'Our all-natural lemonade flavored with real strawberries.',
#   'nome': 'Strawberry Lemonade',
#   'calorie': '230-480 cal',
#   'prezzo': '$2.09-$2.99',
#   'categoria': 'Beverages',
#   'ingredienti': [71680]},
#  {'ID': 30303,
#   'nImmagine': '185',
#   'descrizione': '100% white-meat chicken breaded to crispy perfection and served with your choice of 6 dipping sauces including Buttermilk Ranch, Creamy Sriracha, BBQ, Sweet & Sour, Honey Mustard, or Side of S’Awesome®. They’re trending in our restaurants and Twitter feed alike.',
#   'nome': "Kids' 4PC Nuggets",
#   'calorie': '240-630 cal',
#   'prezzo': '$3.29',
#   'categoria': 'Wendy’s Kids’ Meal',
#   'ingredienti': [71162]},
#  {'ID': 30304,
#   'nImmagine': '186',
#   'descrizione': 'Fresh, never frozen beef and melted American cheese, hot off the grill and topped with ketchup, just the way your child wants it. One of the joys of childhood.',
#   'nome': "Kids' Cheeseburger",
#   'calorie': '310-650 cal',
#   'prezzo': '$3.29',
#   'fk': 40644},
#  {'ID': 30343,
#   'nImmagine': '216',
#   'descrizione': 'Natural, pure, refreshing, and delicious.',
#   'nome': 'Nestlé® Pure Life® Bottled Water',
#   'calorie': '0 cal',
#   'prezzo': '$1.39',
#   'categoria': 'Beverages',
#   'ingredienti': [71795]},
#  {'ID': 30374,
#   'nImmagine': '154',
#   'descrizione': 'Juicy white meat, lightly breaded and seasoned, topped with Applewood smoked bacon, crisp lettuce, tomato, cheese, and mayo. A classic taste, perfectly reinvented.',
#   'nome': 'Crispy Chicken BLT',
#   'calorie': '420 cal',
#   'prezzo': '$1.69',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70201, 70205, 71526, 71609, 71612, 71632, 71050]},
#  {'ID': 30403,
#   'nImmagine': '152',
#   'descrizione': 'Herb-marinated grilled chicken breast topped with smoky honey mustard, crisp spring mix, and tomato, served on a warm toasted bun. See if it isn’t the best chicken sandwich you’ve ever had.',
#   'nome': 'Grilled Chicken Sandwich',
#   'calorie': '370 cal',
#   'prezzo': '$4.59',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70218, 71568, 71571, 71507, 70197]},
#  {'ID': 30404,
#   'nImmagine': '427',
#   'descrizione': 'Herb-marinated grilled chicken breast topped with smoky honey mustard, crisp spring mix, and tomato, served on a warm toasted bun. See if it isn’t the best chicken sandwich you’ve ever had.',
#   'nome': 'Grilled Chicken Sandwich Combo',
#   'calorie': '410-1,020 cal',
#   'prezzo': '$6.59',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70218, 71568, 71571, 71507, 70197]},
#  {'ID': 30435,
#   'nImmagine': '262',
#   'descrizione': 'A quarter-pound* of fresh beef, American cheese, crisp lettuce, tomato, pickle, ketchup, mayo, and onion on a toasted bun — just the way Dave intended.',
#   'nome': "Dave's Single®",
#   'calorie': '610-1,220 cal',
#   'prezzo': '$5.49',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197,
#    70214,
#    70215,
#    71567,
#    71570,
#    71569,
#    71571,
#    71539,
#    70222]},
#  {'ID': 30450,
#   'nImmagine': '160',
#   'descrizione': 'Made fresh daily with Wendy’s signature lettuce blend, shredded cheddar cheese, diced tomatoes, salsa, sour cream, tortilla chips, and our famous, hearty chili. A fresh take on tacos perfect for Tuesdays, Wednesdays, or any other days for that matter.\r\n\r\nNutrition and allergen information is inclusive of all ingredients in this salad.\r\n',
#   'nome': 'Taco Salad',
#   'calorie': '480/690 cal',
#   'prezzo': '$3.99/$5.99',
#   'categoria': 'Fresh-Made Salads',
#   'ingredienti': [71594, 70396, 71593, 71627, 71628]},
#  {'ID': 30469,
#   'nImmagine': '176',
#   'descrizione': 'The satisfying simplicity of good, honest, hot, fluffy baked potato perfection. Ingredients: Potato.',
#   'nome': 'Plain Baked Potato',
#   'calorie': '270 cal',
#   'prezzo': '$0.99',
#   'categoria': 'Fries & Sides',
#   'ingredienti': [71178]},
#  {'ID': 30473,
#   'nImmagine': '432',
#   'descrizione': 'Made fresh daily with Wendy’s signature lettuce blend, pepper jack cheese, diced tomatoes, cool, creamy avocado, Applewood smoked bacon, and grilled chicken breast hot off the grill, all topped with Marzetti® Simply Dressed® Southwest Ranch Dressing. It’s zesty and Southwesty!\r\n\r\nNutrition and allergen information is inclusive of all ingredients in this salad including two packets of dressing on the full-size salad and one packet on the half, which come on the side.\r\n',
#   'nome': 'Southwest Avocado Chicken Salad',
#   'calorie': '300/610 cal',
#   'prezzo': '$4.69/$6.69',
#   'categoria': 'Fresh-Made Salads',
#   'ingredienti': [71616, 71555, 71723, 71615, 71741]},
#  {'ID': 30474,
#   'nImmagine': '183',
#   'descrizione': 'The same great taste as Coke Classic® but with zero calories.',
#   'nome': 'Coca-Cola® Zero Sugar',
#   'calorie': '0 cal',
#   'prezzo': '$1.59-$1.99',
#   'fk': 40749},
#  {'ID': 30476,
#   'nImmagine': '194',
#   'descrizione': 'A sweet, spiced favorite that’s stood the test of time. ',
#   'nome': "Barq's® Root Beer",
#   'calorie': '220-450 cal',
#   'prezzo': '$1.59-$1.99',
#   'fk': 40754,
#   'categoria': 'Beverages'},
#  {'ID': 30515,
#   'nImmagine': '449',
#   'descrizione': 'A selection of crisp, juicy sliced apple pieces, perfect as a snack or a side. Great pick!',
#   'nome': 'Apple Bites',
#   'calorie': '35 cal',
#   'prezzo': '$0.99',
#   'categoria': 'Fries & Sides',
#   'ingredienti': [71712]},
#  {'ID': 30611,
#   'nImmagine': '455',
#   'descrizione': 'Our natural-cut, skin-on, sea-salted fries topped with our hearty chili and rich, creamy cheese sauce. Easy to love. Hard to beat.',
#   'nome': 'Chili Cheese Fries',
#   'calorie': '530 cal',
#   'prezzo': '$2.49',
#   'categoria': 'Fries & Sides',
#   'ingredienti': [71183, 70408, 71695, 70381]},
#  {'ID': 30613,
#   'nImmagine': '269',
#   'descrizione': 'A juicy, lightly breaded chicken breast taken over the top with thick Applewood smoked bacon, Asiago cheese, creamy ranch sauce, crisp lettuce, and tomato, all on a toasted bun. A club favorite that’s anything but boring.',
#   'nome': 'Asiago Ranch Chicken Club Combo',
#   'calorie': '550-1,300 cal',
#   'prezzo': '$6.79',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70197, 70206, 70217, 71567, 71571, 71032, 71508]},
#  {'ID': 30634,
#   'nImmagine': '726',
#   'descrizione': '100% white-meat chicken breaded to crispy perfection and served with your choice of 6 dipping sauces including Buttermilk Ranch, Creamy Sriracha, BBQ, Sweet & Sour, Honey Mustard, or Side of S’Awesome®. They’re trending in our restaurants and Twitter feed alike.',
#   'nome': '6 PC. Crispy Chicken Nuggets',
#   'calorie': '250 cal',
#   'prezzo': '$1.49',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [71161]},
#  {'ID': 30635,
#   'nImmagine': '725',
#   'descrizione': '100% white-meat chicken breaded to crispy perfection and served with your choice of 6 dipping sauces including Buttermilk Ranch, Creamy Sriracha, BBQ, Sweet & Sour, Honey Mustard, or Side of S’Awesome®. They’re trending in our restaurants and Twitter feed alike.',
#   'nome': '4 PC. Crispy Chicken Nuggets',
#   'calorie': '170 cal',
#   'prezzo': '$0.99',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [71162]},
#  {'ID': 30700,
#   'nImmagine': '437',
#   'descrizione': 'A fluffy buttermilk biscuit smothered in white pepper gravy and grilled breakfast sausage. It’s what southern hospitality tastes like.',
#   'nome': 'Sausage Gravy & Biscuit',
#   'calorie': '450 cal',
#   'prezzo': '$2.19',
#   'categoria': 'Biscuits',
#   'ingredienti': [71818, 72340]},
#  {'ID': 30701,
#   'nImmagine': '438',
#   'descrizione': 'A fresh-cracked grade A egg on a fluffy buttermilk biscuit with Applewood smoked bacon and melted American cheese. Rise and shine with a hearty favorite.',
#   'nome': 'Bacon, Egg & Cheese Biscuit',
#   'calorie': '420 cal',
#   'prezzo': '$2.59',
#   'categoria': 'Biscuits',
#   'ingredienti': [71783, 70205, 71786, 72340]},
#  {'ID': 30702,
#   'nImmagine': '439',
#   'descrizione': 'A fresh-cracked grade A egg on a fluffy buttermilk biscuit with grilled sausage and melted American cheese. Meet your new morning favorite.',
#   'nome': 'Sausage, Egg & Cheese Biscuit',
#   'calorie': '610 cal',
#   'prezzo': '$2.59',
#   'categoria': 'Biscuits',
#   'ingredienti': [71781, 71783, 70205, 72340]},
#  {'ID': 30703,
#   'nImmagine': '440',
#   'descrizione': 'A crispy, chicken fillet, perfectly seasoned and topped with maple honey butter on a fluffy buttermilk biscuit. It’s sweet, it’s savory, and it’s a great reason to get out of bed in the morning.',
#   'nome': 'Honey Butter Chicken Biscuit',
#   'calorie': '500 cal',
#   'prezzo': '$2.59',
#   'categoria': 'Biscuits',
#   'ingredienti': [71784, 71780, 72340]},
#  {'ID': 30709,
#   'nImmagine': '446',
#   'descrizione': 'Natural-cut, skin-on potatoes cooked to perfection and seasoned with cracked black pepper and garlic powder.',
#   'nome': 'Seasoned Potatoes',
#   'calorie': '230-410 cal',
#   'prezzo': '$1.29-$1.79',
#   'categoria': 'Sides & More',
#   'ingredienti': [71832]},
#  {'ID': 30711,
#   'nImmagine': '448',
#   'descrizione': 'Grilled, breakfast sausage on a soft buttermilk biscuit. Simple breakfast perfection.',
#   'nome': 'Sausage Biscuit',
#   'calorie': '470 cal',
#   'prezzo': '$0.99',
#   'categoria': 'Biscuits',
#   'ingredienti': [71781, 72340]},
#  {'ID': 30723,
#   'nImmagine': '694',
#   'descrizione': 'Vanilla Frosty® topped with Chocolate Chunk Cookie bites and Ghirardelli® Chocolate Sauce.\r\n',
#   'nome': 'Frosty® Cookie Sundae',
#   'calorie': '380/400 cal',
#   'prezzo': '$1.99',
#   'categoria': 'Frosty',
#   'ingredienti': [71731, 71732, 71736]},
#  {'ID': 30737,
#   'nImmagine': '417',
#   'descrizione': 'A quarter-pound* of fresh beef, crispy fried onions and American cheese, covered in sweet and smoky barbecue sauce all on a toasted bun.\xa0 This stampede of flavor is the best barbecue hamburger in the west–or north or south or east for that matter.',
#   'nome': 'Barbecue Cheeseburger',
#   'calorie': '630 cal',
#   'prezzo': '$4.39',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197, 71772, 71539, 70222, 71634, 71570]},
#  {'ID': 30742,
#   'nImmagine': '414',
#   'descrizione': 'A quarter-pound* of fresh beef, crispy fried onions and American cheese, covered in sweet and smoky barbecue sauce all on a toasted bun.\xa0 This stampede of flavor is the best barbecue hamburger in the west–or north or south or east for that matter.',
#   'nome': 'Barbecue Cheeseburger Combo',
#   'calorie': '670-1,280 cal',
#   'prezzo': '$6.69',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197, 71772, 71539, 70222, 71634, 71570]},
#  {'ID': 30757,
#   'nImmagine': '535',
#   'descrizione': 'Slow steeped, to be extra rich and super-smooth, then served over ice to be extra refreshing and invigorating.',
#   'nome': 'Cold Brew Iced Coffee',
#   'calorie': '15/25 cal',
#   'prezzo': '$2.29/$2.59',
#   'categoria': 'Beverages',
#   'ingredienti': [71824]},
#  {'ID': 30758,
#   'nImmagine': '533',
#   'descrizione': 'Smooth, cold-brewed coffee swirled with our legendary vanilla Frosty mix and served over ice. ',
#   'nome': 'Vanilla Frosty®-ccino',
#   'calorie': '210/310 cal',
#   'prezzo': '$2.49/$2.79',
#   'categoria': 'Beverages',
#   'ingredienti': [71825]},
#  {'ID': 30759,
#   'nImmagine': '534',
#   'descrizione': 'Smooth, cold-brewed coffee swirled with our legendary chocolate Frosty mix and served over ice. ',
#   'nome': 'Chocolate Frosty®-ccino',
#   'calorie': '220/310 cal',
#   'prezzo': '$2.49/$2.79',
#   'categoria': 'Beverages',
#   'ingredienti': [71826]},
#  {'ID': 30794,
#   'nImmagine': '563',
#   'descrizione': 'Grape, strawberry, and watermelon juices unite for a delicious, organic juice.',
#   'nome': 'Honest Kids® Fruit Punch',
#   'calorie': '35 cal',
#   'prezzo': '$0.99',
#   'categoria': 'Beverages',
#   'ingredienti': [71800]},
#  {'ID': 30805,
#   'nImmagine': '573',
#   'descrizione': 'A fresh-cracked grade A egg, Applewood-smoked bacon, and melted American cheese on a warm breakfast roll. A tried and true reason to rise. ',
#   'nome': 'Classic Bacon, Egg & Cheese Sandwich ',
#   'calorie': '320 cal',
#   'prezzo': '$3.49',
#   'categoria': 'Classics',
#   'ingredienti': [71786, 71783, 70205, 72341]},
#  {'ID': 30806,
#   'nImmagine': '572',
#   'descrizione': 'A fresh-cracked grade A egg, grilled sausage and melted American cheese on a warm breakfast roll. It’s how mornings were meant to begin.',
#   'nome': 'Classic Sausage, Egg & Cheese Sandwich',
#   'calorie': '500 cal',
#   'prezzo': '$3.49',
#   'categoria': 'Classics',
#   'ingredienti': [71781, 71783, 70205, 72341]},
#  {'ID': 30813,
#   'nImmagine': '574',
#   'descrizione': 'Herb-marinated grilled chicken breast, Applewood smoked bacon, lettuce, tomato, muenster cheese, cool buttermilk ranch and creamy avocado. It’s the best thing to happen to the BLT since abbreviations.',
#   'nome': 'Grilled Avocado BLT Chicken Sandwich',
#   'calorie': '590 cal',
#   'prezzo': '$5.69',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70765, 71507, 70197, 71600, 71726, 71567, 71571, 70217]},
#  {'ID': 30815,
#   'nImmagine': '575',
#   'descrizione': 'A juicy, lightly breaded chicken breast marinated and breaded in our unique, fiery blend of peppers and spices topped with crispy onions, muenster cheese, pickles, and covered in a sweet and smoky BBQ sauce. There are reasons the west was wild, and this sandwich is as rowdy as any of them.',
#   'nome': 'Spicy Barbecue Chicken Sandwich',
#   'calorie': '650 cal',
#   'prezzo': '$5.19',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70197, 71600, 71634, 71570, 71620, 71772]},
#  {'ID': 30816,
#   'nImmagine': '592',
#   'descrizione': 'Herb-marinated grilled chicken breast, Applewood smoked bacon, lettuce, tomato, muenster cheese, cool buttermilk ranch and creamy avocado. It’s the best thing to happen to the BLT since abbreviations.',
#   'nome': 'Avocado BLT Chicken Sandwich Combo ',
#   'calorie': '640-1,390 cal',
#   'prezzo': '$7.89',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70765, 71507, 70197, 71600, 71726, 71567, 71571, 70217]},
#  {'ID': 30827,
#   'nImmagine': '740',
#   'descrizione': 'A half-pound* of fresh beef, crispy fried onions and American cheese, covered in sweet and smoky barbecue sauce all on a toasted bun.\xa0 This stampede of flavor is the best barbecue hamburger in the west–or north or south or east for that matter.',
#   'nome': 'Barbecue Cheeseburger Double',
#   'calorie': '870 cal',
#   'prezzo': '$5.39',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197, 71772, 71539, 71151, 71634, 71570]},
#  {'ID': 30828,
#   'nImmagine': '742',
#   'descrizione': 'Three quarters of a pound* of fresh, never-frozen beef, crispy fried onions and American cheese, covered in sweet and smoky barbecue sauce all on a toasted bun.\xa0 This stampede of flavor is the best barbecue hamburger in the west–or north or south or east for that matter.',
#   'nome': 'Barbecue Cheeseburger Triple',
#   'calorie': '1,160 cal',
#   'prezzo': '$6.39',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197, 71772, 71557, 71152, 71634, 71570]},
#  {'ID': 30829,
#   'nImmagine': '744',
#   'descrizione': 'A half-pound* of fresh beef, crispy fried onions and American cheese, covered in sweet and smoky barbecue sauce all on a toasted bun.\xa0 This stampede of flavor is the best barbecue hamburger in the west–or north or south or east for that matter.',
#   'nome': 'Barbecue Cheeseburger Double',
#   'calorie': '910-1,530 cal',
#   'prezzo': '$7.69',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197, 71772, 71539, 71151, 71634, 71570]},
#  {'ID': 30830,
#   'nImmagine': '747',
#   'descrizione': 'Three quarters of a pound* of fresh, never-frozen beef, crispy fried onions and American cheese, covered in sweet and smoky barbecue sauce all on a toasted bun.\xa0 This stampede of flavor is the best barbecue hamburger in the west–or north or south or east for that matter.',
#   'nome': 'Barbecue Cheeseburger Triple',
#   'calorie': '1,190-1,810 cal',
#   'prezzo': '$8.99',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197, 71772, 71557, 71152, 71634, 71570]},
#  {'ID': 30836,
#   'nImmagine': '412',
#   'descrizione': 'A quarter-pound* of fresh beef, American cheese, crisp lettuce, tomato, pickle, ketchup, mayo, and onion on a toasted bun — just the way Dave intended.',
#   'nome': "Dave's Combo",
#   'calorie': '610-1,750 cal',
#   'prezzo': '$5.49',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197,
#    70214,
#    70215,
#    71567,
#    71570,
#    71569,
#    71571,
#    71539,
#    70222]},
#  {'ID': 30838,
#   'nImmagine': '413',
#   'descrizione': 'A half-pound* of fresh beef, American cheese, 6 pieces of crispy Applewood smoked bacon, ketchup, and mayo. Carnivores rejoice!',
#   'nome': 'Baconator® Combo',
#   'calorie': '670-1,600 cal',
#   'prezzo': '$7.99',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197, 70214, 70215, 71151, 71179, 71539]},
#  {'ID': 30853,
#   'nImmagine': '776',
#   'descrizione': 'Fresh beef, Applewood smoked bacon, American cheese, crisp lettuce, tomato, and mayo. It’s a favorite of bacon lovers everywhere.',
#   'nome': 'Jr. Bacon Cheeseburger- 4 for $4 Meal',
#   'calorie': '820-1,190 cal',
#   'prezzo': '$4.00',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70201, 70205, 71526, 71609, 71612, 71154, 71048]},
#  {'ID': 30855,
#   'nImmagine': '825',
#   'descrizione': 'A fresh-cracked grade A egg and Applewood smoked bacon covered in creamy swiss cheese sauce on a flaky croissant bun. Breakfast basics worth waking up early for.',
#   'nome': 'Bacon, Egg & Swiss Croissant ',
#   'calorie': '410 cal',
#   'prezzo': '$3.59',
#   'categoria': 'Croissants',
#   'ingredienti': [71860, 71783, 71858, 72339]},
#  {'ID': 30856,
#   'nImmagine': '824',
#   'descrizione': 'A fresh-cracked grade A egg and grilled sausage covered in creamy swiss cheese sauce on a flaky croissant bun. There’s a lot going on in this simple sandwich and it’s all delicious. ',
#   'nome': 'Sausage, Egg & Swiss Croissant ',
#   'calorie': '600 cal',
#   'prezzo': '$3.59',
#   'categoria': 'Croissants',
#   'ingredienti': [71859, 71783, 71858, 72339]},
#  {'ID': 30857,
#   'nImmagine': '823',
#   'descrizione': 'A juicy chicken breast, Applewood smoked bacon, and maple butter on a flaky croissant bun. A little sweet. A little savory. A lot good.',
#   'nome': 'Maple Bacon Chicken Croissant',
#   'calorie': '560 cal',
#   'prezzo': '$3.99',
#   'categoria': 'Croissants',
#   'ingredienti': [71784, 71860, 71861, 72339]},
#  {'ID': 30858,
#   'nImmagine': '447',
#   'descrizione': 'Scrambled eggs, melty cheese, and perfectly seasoned breakfast sausage wrapped in a warm, soft, flour tortilla. Conveniently delicious, and deliciously convenient.',
#   'nome': 'Sausage, Egg & Cheese Burrito ',
#   'calorie': '340 cal',
#   'prezzo': '$1.39',
#   'categoria': 'Sides & More',
#   'ingredienti': [71836]},
#  {'ID': 30860,
#   'nImmagine': '826',
#   'descrizione': 'Grilled sausage, American cheese, Applewood smoked bacon, a fresh-cracked grade A egg, (deep breath) more cheese and more bacon all covered in swiss cheese sauce. Don’t just break your fast. Destroy it. ',
#   'nome': 'Breakfast Baconator™',
#   'calorie': '730 cal',
#   'prezzo': '$3.99',
#   'categoria': 'Classics',
#   'ingredienti': [71787, 71858, 71539, 72345, 71781, 71783]},
#  {'ID': 30861,
#   'nImmagine': '829',
#   'descrizione': '100% Pure squeezed pasteurized orange juice. A delicious orange juice with a taste that’s the next best thing to fresh squeezed.',
#   'nome': 'Simply Orange® Juice',
#   'calorie': '160 cal',
#   'prezzo': '$2.39',
#   'categoria': 'Beverages',
#   'ingredienti': [71864]},
#  {'ID': 30862,
#   'nImmagine': '827',
#   'descrizione': 'Fluffy buttermilk biscuit spread with maple honey butter. The kind of down-home breakfast that melts in your mouth and makes you reminisce about the farm, even if you’re from the city.',
#   'nome': 'Honey Butter Biscuit',
#   'calorie': '310 cal',
#   'prezzo': '$1.09',
#   'categoria': 'Biscuits',
#   'ingredienti': [71784]},
#  {'ID': 30863,
#   'nImmagine': '830',
#   'descrizione': 'Our all-natural lemonade mixed with real peach puree. \r\n',
#   'nome': 'Peach Lemonade',
#   'calorie': '220-440 cal',
#   'prezzo': '$2.29-$2.99',
#   'categoria': 'Beverages',
#   'ingredienti': [71717]},
#  {'ID': 30864,
#   'nImmagine': '831',
#   'descrizione': 'Our all-natural lemonade mixed with beachy flavors like strawberries, dragon fruit and passion fruit.\xa0 ',
#   'nome': 'Tropical Berry Lemonade',
#   'calorie': '230-460 cal',
#   'prezzo': '$2.29-$2.99',
#   'categoria': 'Beverages',
#   'ingredienti': [71720]},
#  {'ID': 30884,
#   'nImmagine': '864',
#   'descrizione': 'A juicy, lightly breaded chicken breast, crispy onions, muenster cheese, pickles, and covered in a sweet and smoky BBQ sauce. There are reasons the west was wild, and this sandwich is as rowdy as any of them.',
#   'nome': 'Homestyle Barbecue Chicken Sandwich',
#   'calorie': '650 cal',
#   'prezzo': '$5.19',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [71508, 70197, 71772, 71600, 71634, 71570]},
#  {'ID': 30885,
#   'nImmagine': '865',
#   'descrizione': 'Herb-marinated grilled chicken breast, crispy onions, muenster cheese, pickles, and covered in a sweet and smoky BBQ sauce. There are reasons the west was wild, and this sandwich is as rowdy as any of them.',
#   'nome': 'Grilled Barbecue Chicken Sandwich',
#   'calorie': '520 cal',
#   'prezzo': '$5.19',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [71507, 70197, 71772, 71600, 71570, 71634]},
#  {'ID': 30888,
#   'nImmagine': '869',
#   'descrizione': 'A juicy, lightly breaded chicken breast marinated and breaded in our unique, fiery blend of peppers and spices topped with Applewood smoked bacon, lettuce, tomato, muenster cheese, cool buttermilk ranch and creamy avocado. It’s the best thing to happen to the BLT since abbreviations.',
#   'nome': 'Spicy Avocado BLT Chicken Sandwich ',
#   'calorie': '720 cal',
#   'prezzo': '$5.69',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70197, 71600, 71726, 71567, 71571, 71032, 71620, 70217]},
#  {'ID': 30889,
#   'nImmagine': '868',
#   'descrizione': 'A juicy, lightly breaded chicken breast, Applewood smoked bacon, lettuce, tomato, muenster cheese, cool buttermilk ranch and creamy avocado. It’s the best thing to happen to the BLT since abbreviations.',
#   'nome': 'Homestyle Avocado BLT Chicken Sandwich',
#   'calorie': '720 cal',
#   'prezzo': '$5.69',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [71032, 71508, 70197, 70217, 71600, 71726, 71571, 71567]},
#  {'ID': 30890,
#   'nImmagine': '870',
#   'descrizione': 'A juicy, lightly breaded chicken breast, crispy onions, muenster cheese, pickles, and covered in a sweet and smoky BBQ sauce. There are reasons the west was wild, and this sandwich is as rowdy as any of them.',
#   'nome': 'Homestyle Barbecue Chicken Sandwich',
#   'calorie': '690-1,310 cal',
#   'prezzo': '$7.39',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [71508, 70197, 71772, 71600, 71634, 71570]},
#  {'ID': 30891,
#   'nImmagine': '871',
#   'descrizione': 'Herb-marinated grilled chicken breast, crispy onions, muenster cheese, pickles, and covered in a sweet and smoky BBQ sauce. There are reasons the west was wild, and this sandwich is as rowdy as any of them.',
#   'nome': 'Grilled Barbecue Chicken Sandwich',
#   'calorie': '560-1,170 cal',
#   'prezzo': '$7.39',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [71507, 70197, 71772, 71600, 71570, 71634]},
#  {'ID': 30894,
#   'nImmagine': '878',
#   'descrizione': 'A juicy, lightly breaded chicken breast marinated and breaded in our unique, fiery blend of peppers and spices topped with Applewood smoked bacon, lettuce, tomato, muenster cheese, cool buttermilk ranch and creamy avocado. It’s the best thing to happen to the BLT since abbreviations.',
#   'nome': 'Spicy Avocado BLT Chicken Sandwich ',
#   'calorie': '770-1,390 cal',
#   'prezzo': '$7.89',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70197, 71600, 71726, 71567, 71571, 71032, 71620, 70217]},
#  {'ID': 30895,
#   'nImmagine': '877',
#   'descrizione': 'A juicy, lightly breaded chicken breast, Applewood smoked bacon, lettuce, tomato, muenster cheese, cool buttermilk ranch and creamy avocado. It’s the best thing to happen to the BLT since abbreviations.',
#   'nome': 'Homestyle Avocado BLT Chicken Sandwich',
#   'calorie': '780-1,390 cal',
#   'prezzo': '$7.89',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [71032, 71508, 70197, 70217, 71600, 71726, 71571, 71567]},
#  {'ID': 30896,
#   'nImmagine': '593',
#   'descrizione': 'A juicy, lightly breaded chicken breast marinated and breaded in our unique, fiery blend of peppers and spices topped with crispy onions, muenster cheese, pickles, and covered in a sweet and smoky BBQ sauce. There are reasons the west was wild, and this sandwich is as rowdy as any of them.',
#   'nome': 'Barbecue Chicken Sandwich Combo ',
#   'calorie': '550-1,300 cal',
#   'prezzo': '$7.39',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70197, 71600, 71634, 71570, 71620, 71772]},
#  {'ID': 30898,
#   'nImmagine': '592',
#   'descrizione': 'Herb-marinated grilled chicken breast, Applewood smoked bacon, lettuce, tomato, muenster cheese, cool buttermilk ranch and creamy avocado. It’s the best thing to happen to the BLT since abbreviations.',
#   'nome': 'Avocado BLT Chicken Sandwich Combo ',
#   'calorie': '640-1,390 cal',
#   'prezzo': '$7.89',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70765, 71507, 70197, 71600, 71726, 71567, 71571, 70217]},
#  {'ID': 30899,
#   'nImmagine': '414',
# ...
#   'nome': 'Barbecue Cheeseburger Combo',
#   'calorie': '670-1,280 cal',
#   'prezzo': '$6.69',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197, 71772, 71539, 70222, 71634, 71570]},
#  {'ID': 30907,
#   'nImmagine': '779',
#   'descrizione': 'Juicy white meat, lightly breaded and seasoned, topped with crisp lettuce, and mayo. More than delicious, and just the right size.',
#   'nome': 'Crispy Chicken Sandwich- 4 for $4 Meal',
#   'calorie': '770-1,150 cal',
#   'prezzo': '$4.00',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70201, 71526, 71609, 71050]},
#  {'ID': 30908,
#   'nImmagine': '775',
#   'descrizione': 'Fresh beef topped with cheese, pickles, onion, ketchup, and mustard on a toasted bun. It’s done just right, and just the right size.',
#   'nome': 'Jr. Cheeseburger- 4 for $4 Meal',
#   'calorie': '720-1,100 cal',
#   'prezzo': '$4.00',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70201, 70205, 71530, 71527, 71610, 71611, 71048]},
#  {'ID': 30914,
#   'nImmagine': '835',
#   'descrizione': 'A juicy chicken breast, Applewood smoked bacon, and maple butter on a flaky croissant bun. A little sweet. A little savory. A lot good.',
#   'nome': 'Maple Bacon Chicken Croissant Combo',
#   'calorie': '590-1,200 cal',
#   'prezzo': '$5.99',
#   'categoria': 'Croissants',
#   'ingredienti': [71784, 71860, 71861, 72339]},
#  {'ID': 30915,
#   'nImmagine': '836',
#   'descrizione': 'A fresh-cracked grade A egg and grilled sausage covered in creamy swiss cheese sauce on a flaky croissant bun. There’s a lot going on in this simple sandwich and it’s all delicious. ',
#   'nome': 'Sausage, Egg & Swiss Croissant Combo',
#   'calorie': '630-1,240 cal',
#   'prezzo': '$5.59',
#   'categoria': 'Croissants',
#   'ingredienti': [71859, 71783, 71858, 72339]},
#  {'ID': 30917,
#   'nImmagine': '837',
#   'descrizione': 'A fresh-cracked grade A egg and Applewood smoked bacon covered in creamy swiss cheese sauce on a flaky croissant bun. Breakfast basics worth waking up early for.',
#   'nome': 'Bacon, Egg & Swiss Croissant Combo',
#   'calorie': '450-1,060 cal',
#   'prezzo': '$5.59',
#   'categoria': 'Croissants',
#   'ingredienti': [71860, 71783, 71858, 72339]},
#  {'ID': 30918,
#   'nImmagine': '839',
#   'descrizione': 'A fresh-cracked grade A egg on a fluffy buttermilk biscuit with grilled sausage and melted American cheese. Meet your new morning favorite.',
#   'nome': 'Sausage, Egg & Cheese Biscuit Combo',
#   'calorie': '640-1,250 cal',
#   'prezzo': '$4.29',
#   'categoria': 'Biscuits',
#   'ingredienti': [71781, 71783, 70205, 72340]},
#  {'ID': 30919,
#   'nImmagine': '840',
#   'descrizione': 'A fresh-cracked grade A egg on a fluffy buttermilk biscuit with Applewood smoked bacon and melted American cheese. Rise and shine with a hearty favorite.',
#   'nome': 'Bacon, Egg & Cheese Biscuit Combo',
#   'calorie': '460-1,060 cal',
#   'prezzo': '$4.29',
#   'categoria': 'Biscuits',
#   'ingredienti': [71783, 70205, 71786, 72340]},
#  {'ID': 30920,
#   'nImmagine': '838',
#   'descrizione': 'A crispy, chicken fillet, perfectly seasoned and topped with maple honey butter on a fluffy buttermilk biscuit. It’s sweet, it’s savory, and it’s a great reason to get out of bed in the morning.',
#   'nome': 'Honey Butter Chicken Biscuit Combo',
#   'calorie': '530-1,140 cal',
#   'prezzo': '$4.49',
#   'categoria': 'Biscuits',
#   'ingredienti': [71784, 71780, 72340]},
#  {'ID': 30921,
#   'nImmagine': '904',
#   'descrizione': 'A quarter-pound* of fresh beef topped with pickled jalapeños, Applewood smoked bacon, American cheese, crispy fried onions, a savory cheese sauce and a smoky jalapeño sauce. It’s too hot to not.',
#   'nome': 'Bacon Jalapeño Cheeseburger',
#   'calorie': '740 cal',
#   'prezzo': '$4.99',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197, 71886, 71147, 70222, 71887, 71634, 71539, 71888]},
#  {'ID': 30922,
#   'nImmagine': '905',
#   'descrizione': 'A half-pound* of fresh beef topped with pickled jalapeños, Applewood smoked bacon, American cheese, crispy fried onions, a savory cheese sauce and a smoky jalapeño sauce. Only for those serious about spice.',
#   'nome': 'Bacon Jalapeño Cheeseburger Double ',
#   'calorie': '980 cal',
#   'prezzo': '$5.99',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197, 71886, 71539, 71888, 71151, 71147, 71887, 71634]},
#  {'ID': 30923,
#   'nImmagine': '906',
#   'descrizione': 'Three quarters of a pound* of fresh, never-frozen beef topped with pickled jalapeños, Applewood smoked bacon, American cheese, crispy fried onions, a savory cheese sauce and a smoky jalapeño sauce. It’s a whole lotta heat to eat.',
#   'nome': 'Bacon Jalapeño Cheeseburger Triple',
#   'calorie': '1,260 cal',
#   'prezzo': '$6.99',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197, 71886, 71557, 71888, 71152, 71147, 71887, 71634]},
#  {'ID': 30924,
#   'nImmagine': '907',
#   'descrizione': 'A quarter-pound* of fresh beef topped with pickled jalapeños, Applewood smoked bacon, American cheese, crispy fried onions, a savory cheese sauce and a smoky jalapeño sauce. It’s too hot to not.',
#   'nome': 'Bacon Jalapeño Cheeseburger Combo',
#   'calorie': '790-1,400 cal',
#   'prezzo': '$7.29',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197, 71886, 71147, 70222, 71887, 71634, 71539, 71888]},
#  {'ID': 30925,
#   'nImmagine': '908',
#   'descrizione': 'A half-pound* of fresh beef topped with pickled jalapeños, Applewood smoked bacon, American cheese, crispy fried onions, a savory cheese sauce and a smoky jalapeño sauce. Only for those serious about spice.',
#   'nome': 'Double Bacon Jalapeño Cheeseburger',
#   'calorie': '1,030-1,650 cal',
#   'prezzo': '$8.29',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197, 71886, 71539, 71888, 71151, 71147, 71887, 71634]},
#  {'ID': 30926,
#   'nImmagine': '909',
#   'descrizione': 'Three quarters of a pound* of fresh, never-frozen beef topped with pickled jalapeños, Applewood smoked bacon, American cheese, crispy fried onions, a savory cheese sauce and a smoky jalapeño sauce. It’s a whole lotta heat to eat.',
#   'nome': 'Triple Bacon Jalapeño Cheeseburger',
#   'calorie': '1,310-1,930 cal',
#   'prezzo': '$9.29',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197, 71886, 71557, 71888, 71152, 71147, 71887, 71634]},
#  {'ID': 30927,
#   'nImmagine': '913',
#   'descrizione': 'Kick your fries up a notch with jalapenos, shredded cheddar, Applewood smoked bacon, and warm cheddar cheese sauce drizzled over natural cut, sea salt fries.\r\n',
#   'nome': 'Bacon Jalapeño Cheese Fries',
#   'calorie': '540 cal',
#   'prezzo': '$2.69',
#   'categoria': 'Fries & Sides',
#   'ingredienti': [71709, 70382, 70408, 70381, 71887, 71889, 71662]},
#  {'ID': 30928,
#   'nImmagine': '841',
#   'descrizione': 'Grilled sausage, American cheese, Applewood smoked bacon, a fresh-cracked grade A egg, (deep breath) more cheese and more bacon all covered in swiss cheese sauce. Don’t just break your fast. Destroy it. ',
#   'nome': 'Breakfast Baconator™ Combo',
#   'calorie': '770-1,380 cal',
#   'prezzo': '$5.99',
#   'categoria': 'Classics',
#   'ingredienti': [71787, 71858, 71539, 72345, 71781, 71783]},
#  {'ID': 30929,
#   'nImmagine': '842',
#   'descrizione': 'A fresh-cracked grade A egg, grilled sausage and melted American cheese on a warm breakfast roll. It’s how mornings were meant to begin.',
#   'nome': 'Classic Sausage, Egg & Cheese Sandwich Combo',
#   'calorie': '540-1,150 cal',
#   'prezzo': '$5.49',
#   'categoria': 'Classics',
#   'ingredienti': [71781, 71783, 70205, 72341]},
#  {'ID': 30930,
#   'nImmagine': '843',
#   'descrizione': 'A fresh-cracked grade A egg, Applewood-smoked bacon, and melted American cheese on a warm breakfast roll. A tried and true reason to rise. ',
#   'nome': 'Classic Bacon, Egg & Cheese Sandwich Combo',
#   'calorie': '350-960 cal',
#   'prezzo': '$5.49',
#   'categoria': 'Classics',
#   'ingredienti': [71786, 71783, 70205, 72341]},
#  {'ID': 30941,
#   'nImmagine': '907',
#   'descrizione': 'A quarter-pound* of fresh beef topped with pickled jalapeños, Applewood smoked bacon, American cheese, crispy fried onions, a savory cheese sauce and a smoky jalapeño sauce. It’s too hot to not.',
#   'nome': 'Bacon Jalapeño Cheeseburger Combo',
#   'calorie': '790-1,400 cal',
#   'prezzo': '$7.29',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197, 71886, 71147, 70222, 71887, 71634, 71539, 71888]},
#  {'ID': 30944,
#   'nImmagine': '933',
#   'descrizione': 'A juicy chicken breast marinated and breaded in our unique, fiery blend of peppers and spices taken to the next level with pickled jalapeños, Applewood smoked bacon, American cheese, crispy fried onions, a savory cheese sauce and a smoky jalapeño sauce. Eat the heat.',
#   'nome': 'Bacon Jalapeño Chicken',
#   'calorie': '720 cal',
#   'prezzo': '$4.99',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70197, 71886, 71887, 71634, 70765, 71620, 70205, 71888]},
#  {'ID': 30945,
#   'nImmagine': '936',
#   'descrizione': 'A juicy chicken breast marinated and breaded in our unique, fiery blend of peppers and spices taken to the next level with pickled jalapeños, Applewood smoked bacon, American cheese, crispy fried onions, a savory cheese sauce and a smoky jalapeño sauce. Eat the heat.',
#   'nome': 'Bacon Jalapeño Chicken Combo',
#   'calorie': '640-1,390 cal',
#   'prezzo': '$7.69',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70197, 71886, 71887, 71634, 70765, 71620, 70205, 71888]},
#  {'ID': 30946,
#   'nImmagine': '934',
#   'descrizione': 'A juicy chicken breast marinated and breaded in our unique, fiery blend of peppers and spices taken to the next level with pickled jalapeños, Applewood smoked bacon, American cheese, crispy fried onions, a savory cheese sauce and a smoky jalapeño sauce. Eat the heat.',
#   'nome': 'Homestyle Bacon Jalapeño Chicken',
#   'calorie': '720 cal',
#   'prezzo': '$4.99',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70765, 71508, 70197, 71886, 71887, 71634, 70205, 71888]},
#  {'ID': 30947,
#   'nImmagine': '935',
#   'descrizione': 'A juicy chicken breast marinated and breaded in our unique, fiery blend of peppers and spices taken to the next level with pickled jalapeños, Applewood smoked bacon, American cheese, crispy fried onions, a savory cheese sauce and a smoky jalapeño sauce. Eat the heat.',
#   'nome': 'Grilled Bacon Jalapeño Chicken',
#   'calorie': '590 cal',
#   'prezzo': '$4.99',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70765, 71507, 70197, 71886, 71887, 71634, 70205, 71888]},
#  {'ID': 30949,
#   'nImmagine': '940',
#   'descrizione': 'A juicy chicken breast marinated and breaded in our unique, fiery blend of peppers and spices taken to the next level with pickled jalapeños, Applewood smoked bacon, American cheese, crispy fried onions, a savory cheese sauce and a smoky jalapeño sauce. Eat the heat.',
#   'nome': 'Grilled Bacon Jalapeño Chicken',
#   'calorie': '640-1,250 cal',
#   'prezzo': '$7.69',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70765, 71507, 70197, 71886, 71887, 71634, 70205, 71888]},
#  {'ID': 30953,
#   'nImmagine': '936',
#   'descrizione': 'A juicy chicken breast marinated and breaded in our unique, fiery blend of peppers and spices taken to the next level with pickled jalapeños, Applewood smoked bacon, American cheese, crispy fried onions, a savory cheese sauce and a smoky jalapeño sauce. Eat the heat.',
#   'nome': 'Bacon Jalapeño Chicken Combo',
#   'calorie': '640-1,390 cal',
#   'prezzo': '$7.69',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [70197, 71886, 71887, 71634, 70765, 71620, 70205, 71888]},
#  {'ID': 30954,
#   'nImmagine': '271',
#   'descrizione': '100% white-meat chicken breaded to crispy perfection and served with your choice of 6 dipping sauces including Buttermilk Ranch, Creamy Sriracha, BBQ, Sweet & Sour, Honey Mustard, or Side of S’Awesome®. They’re trending in our restaurants and Twitter feed alike.',
#   'nome': '10 PC. Nuggets Combo',
#   'calorie': '540-1,260 cal',
#   'prezzo': '$5.39',
#   'categoria': 'Chicken, Wraps & More',
#   'ingredienti': [71160]},
#  {'ID': 31071,
#   'nImmagine': '1148',
#   'descrizione': 'A quarter-pound* of fresh beef, Applewood smoked bacon, American cheese, crisp lettuce, tomato, pickle, ketchup, mayo, and onion on a toasted bun. It’s big. It’s classic. It’s got bacon.\r\n',
#   'nome': 'Big Bacon Classic',
#   'calorie': '630 cal',
#   'prezzo': '$3.99',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197,
#    70214,
#    70215,
#    71539,
#    71147,
#    70222,
#    71567,
#    71570,
#    71569,
#    71571]},
#  {'ID': 31076,
#   'nImmagine': '1165',
#   'descrizione': 'A half-pound* of fresh beef, Applewood smoked bacon, American cheese, crisp lettuce, tomato, pickle, ketchup, mayo, and onion on a toasted bun. It’s big. It’s classic. It’s got bacon.',
#   'nome': 'Big Bacon Classic Double',
#   'calorie': '870 cal',
#   'prezzo': '$5.99',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197,
#    70214,
#    70215,
#    71539,
#    71147,
#    71567,
#    71570,
#    71569,
#    71571,
#    71151]},
#  {'ID': 31077,
#   'nImmagine': '1168',
#   'descrizione': 'Three quarters of a pound* of fresh, never-frozen beef, Applewood smoked bacon, American cheese, crisp lettuce, tomato, pickle, ketchup, mayo, and onion on a toasted bun. It’s big. It’s classic. It’s got bacon.\r\n',
#   'nome': 'Big Bacon Classic Triple',
#   'calorie': '1,150 cal',
#   'prezzo': '$6.99',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197,
#    70214,
#    70215,
#    71557,
#    71152,
#    71147,
#    71567,
#    71570,
#    71569,
#    71571]},
#  {'ID': 31078,
#   'nImmagine': '1151',
#   'descrizione': 'A quarter-pound* of fresh beef, Applewood smoked bacon, American cheese, crisp lettuce, tomato, pickle, ketchup, mayo, and onion on a toasted bun. It’s big. It’s classic. It’s got bacon.\r\n',
#   'nome': 'Big Bacon Classic Combo',
#   'calorie': '660-1,230 cal',
#   'prezzo': '$5.49',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197,
#    70214,
#    70215,
#    71539,
#    71147,
#    70222,
#    71567,
#    71570,
#    71569,
#    71571]},
#  {'ID': 31079,
#   'nImmagine': '1175',
#   'descrizione': 'A half-pound* of fresh beef, Applewood smoked bacon, American cheese, crisp lettuce, tomato, pickle, ketchup, mayo, and onion on a toasted bun. It’s big. It’s classic. It’s got bacon.',
#   'nome': 'Big Bacon Classic Double',
#   'calorie': '910-1,470 cal',
#   'prezzo': '$8.49',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197,
#    70214,
#    70215,
#    71539,
#    71147,
#    71567,
#    71570,
#    71569,
#    71571,
#    71151]},
#  {'ID': 31080,
#   'nImmagine': '1176',
#   'descrizione': 'Three quarters of a pound* of fresh, never-frozen beef, Applewood smoked bacon, American cheese, crisp lettuce, tomato, pickle, ketchup, mayo, and onion on a toasted bun. It’s big. It’s classic. It’s got bacon.\r\n',
#   'nome': 'Big Bacon Classic Triple',
#   'calorie': '1,190-1,760 cal',
#   'prezzo': '$9.49',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197,
#    70214,
#    70215,
#    71557,
#    71152,
#    71147,
#    71567,
#    71570,
#    71569,
#    71571]},
#  {'ID': 31100,
#   'nImmagine': '1151',
#   'descrizione': 'A quarter-pound* of fresh beef, Applewood smoked bacon, American cheese, crisp lettuce, tomato, pickle, ketchup, mayo, and onion on a toasted bun. It’s big. It’s classic. It’s got bacon.\r\n',
#   'nome': 'Big Bacon Classic Combo',
#   'calorie': '660-1,230 cal',
#   'prezzo': '$5.49',
#   'categoria': 'Cheeseburgers',
#   'ingredienti': [70197,
#    70214,
#    70215,
#    71539,
#    71147,
#    70222,
#    71567,
#    71570,
#    71569,
#    71571]},
#  {'ID': 31184,
#   'nImmagine': '433',
#   'descrizione': 'Made fresh daily with our Wendy’s signature lettuce blend, herb-marinated grilled chicken breast, a three-cheese blend of Parmesan, Asiago, and Fontina, Applewood smoked bacon, and, of course, strawberries. All topped with candied almonds and Marzetti®¿ Simply Dressed® Champagne Vinaigrette. Raise a glass because this tasty of a salad deserves a toast.',
#   'nome': 'Summer Strawberry Salad',
#   'calorie': '290/530 cal',
#   'prezzo': '$5.19/$7.19',
#   'categoria': 'Fresh-Made Salads',
#   'ingredienti': [71551, 71553, 71885, 71555, 71741]}]

# %%
with open("menu.json", "w") as writefile:
    json.dump(menu, writefile, indent=1)

# %%
ingredienti=[]
for i in range (0, len(modifiers)):
    try:
        item={"ID": modifiers[i]["modifierId"],"nome":modifiers[i]["displayName"],\
       "descrizione": modifiers[i]["description"]}
        ingredienti.append(item)
    except KeyError: pass

# %%
with open("ingredienti.json", "w") as writefile:
    json.dump(ingredienti, writefile, indent=1)

# %%
import requests

Picture_request = requests.get("https://invezz.com/wp-content/uploads/2020/07/dogecoins-strongest-support-broke-for-the-second-time-in-2020.jpg")
if Picture_request.status_code == 200:
    with open("image.jpg", 'wb') as f:
        f.write(Picture_request.content)
